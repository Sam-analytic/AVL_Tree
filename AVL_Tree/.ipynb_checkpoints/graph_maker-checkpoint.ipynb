# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd
from matplotlib import figure

graph_data = pd.read_excel('time_insertion_deletion_AVL.xlsx')
df_graph = pd.DataFrame(graph_data)

df_insertion = df_graph['time_insertion']
df_deletion = df_graph['time_deletion']
new_time_insertion = [0.001517,0.001477,0.00146,0.001508,0.001466,0.001507,0.00146,0.0015,0.001483,0.001514,0.001461,0.001615,0.001584,0.001466,0.001507,0.001462,0.001484,0.001469,0.001463,0.001478,0.001472,0.001496,0.001463,0.001489,0.001772,0.001485,0.001463,0.001463,0.001487,0.001465,0.001487,0.00147,0.001484,0.001465,0.001465,0.001466,0.001466,0.001476,0.001464,0.001487,0.001462,0.001464,0.001503,0.001491,0.001478,0.001462,0.001517,0.001482,0.001507,0.001475,0.00147,0.00151,0.001462,0.001481,0.001483,0.001482,0.001463,0.001468,0.001479,0.001471,0.001472,0.001467,0.001487,0.001461,0.001468,0.001497,0.001462,0.001476,0.001474,0.001478,0.001462,0.001464,0.001509,0.001463,0.001519,0.001471,0.001484,0.001483,0.001464,0.001481,0.001467,0.001479,0.001461,0.00149,0.00146,0.001499,0.001483,0.001471,0.001522,0.001469,0.001487,0.001468,0.001466,0.00147,0.001466,0.001482,0.00146,0.001483,0.001471,0.001464,0.001477,0.001495,0.001487,0.001461,0.001483,0.001468,0.001462,0.001463,0.001469,0.001475,0.001461,0.001487,0.00148,0.001464,0.00146,0.001471,0.001477,0.001471,0.001482,0.001469,0.001462,0.001462,0.001507,0.001498,0.001462,0.001477,0.001466,0.00146,0.001463,0.00147,0.00151,0.001461,0.00148,0.00147,0.001479,0.00148,0.00147,0.001483,0.001461,0.001476,0.00147,0.00149,0.001463,0.001467,0.001482,0.001465,0.001482,0.00147,0.00153,0.001464,0.001464,0.001504,0.001467,0.001494,0.001472,0.001502,0.001468,0.001466,0.001514,0.001526,0.001503,0.001466,0.001488,0.001469,0.001466,0.001463,0.001468,0.001479,0.001463,0.001511,0.001486,0.001463,0.001462,0.001467,0.001482,0.001477,0.001484,0.001469,0.001465,0.001464,0.001469,0.0015,0.001462,0.001478,0.001469,0.001466,0.001463,0.001471,0.001509,0.001466,0.001503,0.001467,0.001478,0.001473,0.001466,0.001482,0.001493,0.001483,0.001471,0.001481,0.001468,0.001464,0.001493,0.001465,0.001502,0.001476,0.001483,0.001464,0.001548,0.001511,0.001496,0.001521,0.001531,0.001506,0.001494,0.001496,0.001535,0.00154,0.001501,0.001473,0.001491,0.001467,0.001473,0.001473,0.001661,0.001475,0.001482,0.001511,0.001466,0.001494,0.001464,0.001477,0.001479,0.001471,0.001479,0.001467,0.001482,0.001461,0.001483,0.001485,0.001469,0.001485,0.001459,0.001494,0.001465,0.001475,0.00156,0.001472,0.001484,0.001466,0.001504,0.001471,0.00148,0.001469,0.00147,0.00147,0.001465,0.001483,0.001477,0.001486,0.001469,0.001479,0.001498,0.001468,0.001492,0.00147,0.001495,0.00147,0.001485,0.001486,0.001472,0.001483,0.001562,0.001543,0.001471,0.001503,0.001467,0.001468,0.001502,0.001474,0.001488,0.001467,0.001509,0.001467,0.001476,0.001485,0.001466,0.001582,0.00147,0.001493,0.001472,0.001502,0.001473,0.001466,0.001483,0.001469,0.001523,0.001464,0.001479,0.001472,0.001468,0.00148,0.00147,0.001485,0.001464,0.001505,0.001473,0.001469,0.0015,0.001465,0.001481,0.001467,0.001476,0.001466,0.001471,0.001479,0.001462,0.001492,0.001471,0.00148,0.001478,0.001466,0.001474,0.001465,0.001523,0.001475,0.001482,0.001467,0.001471,0.001464,0.001464,0.001503,0.001466,0.001516,0.001465,0.001473,0.001472,0.001465,0.001477,0.001471,0.001484,0.001753,0.001499,0.001486,0.001501,0.001485,0.001475,0.001485,0.001479,0.001476,0.001467,0.001474,0.001483,0.001466,0.001502,0.00147,0.001481,0.001465,0.001486,0.001469,0.001462,0.001552,0.001504,0.001496,0.001467,0.001474,0.001487,0.001465,0.001482,0.001472,0.001485,0.00147,0.001481,0.001488,0.001466,0.001486,0.001472,0.001485,0.001466,0.00148,0.001471,0.00147,0.001489,0.001473,0.001482,0.001465,0.00148,0.001484,0.001469,0.00151,0.001463,0.00152,0.001465,0.001505,0.001474,0.00147,0.001483,0.001467,0.001557,0.001484,0.001487,0.001484,0.001473,0.001469,0.001467,0.001486,0.001814,0.001504,0.001471,0.001486,0.001474,0.001472,0.001504,0.001467,0.001491,0.001473,0.001485,0.00147,0.001474,0.001517,0.001468,0.001516,0.001475,0.001486,0.001488,0.001465,0.001472,0.001467,0.001497,0.001473,0.001487,0.00147,0.001479,0.001475,0.001471,0.001542,0.001477,0.001491,0.001463,0.001491,0.001475,0.00147,0.001481,0.001465,0.001509,0.001469,0.001489,0.001479,0.001507,0.001496,0.001469,0.001493,0.001473,0.00168,0.001465,0.001481,0.001472,0.001469,0.001497,0.001477,0.001484,0.001465,0.001477,0.001477,0.001476,0.001488,0.001467,0.001486,0.001479,0.001479,0.001488,0.00147,0.00153,0.001469,0.001496,0.001471,0.001482,0.001502,0.001476,0.001466,0.001469,0.001502,0.001475,0.001484,0.001467,0.001485,0.00152,0.001466,0.001489,0.001475,0.001483,0.00147,0.001475,0.001489,0.001465,0.0015,0.001475,0.001498,0.001513,0.001498,0.001479,0.001471,0.00149,0.001466,0.001815,0.001738,0.001562,0.001479,0.001604,0.00147,0.001504,0.001476,0.00147,0.001521,0.00147,0.001495,0.001468,0.001514,0.001473,0.001473,0.001489,0.001479,0.001513,0.001476,0.001487,0.001464,0.001479,0.001496,0.001612,0.001555,0.001493,0.001496,0.001479,0.001494,0.001471,0.00147,0.00152,0.001474,0.001511,0.001468,0.001491,0.001473,0.001468,0.001465,0.001489,0.00149,0.00148,0.00149,0.001473,0.001481,0.001485,0.00147,0.001492,0.001478,0.0015,0.001525,0.001508,0.001468,0.001468,0.00149,0.001509,0.001487,0.001468,0.00159,0.001513,0.001465,0.001471,0.001475,0.001493,0.001471,0.001492,0.001479,0.001478,0.001483,0.001469,0.0015,0.001472,0.001484,0.001488,0.001484,0.001472,0.001467,0.001487,0.001474,0.001486,0.001466,0.00149,0.001466,0.001472,0.001495,0.001487,0.001514,0.001503,0.001512,0.001478,0.001476,0.001482,0.001475,0.001519,0.001484,0.001518,0.001635,0.00167,0.001477,0.001479,0.001465,0.001475,0.001502,0.00147,0.001489,0.001476,0.001508,0.001492,0.001477,0.001492,0.001483,0.00148,0.00163,0.001767,0.001494,0.001521,0.001498,0.001475,0.001514,0.001474,0.001503,0.00147,0.00151,0.001488,0.001474,0.001487,0.001479,0.001493,0.001469,0.001484,0.001486,0.001468,0.001529,0.001477,0.0015,0.001478,0.001495,0.001477,0.00149,0.001594,0.001708,0.001473,0.001481,0.001495,0.001502,0.001491,0.00151,0.001502,0.00149,0.00147,0.001491,0.001476,0.00148,0.001482,0.001492,0.00149,0.001471,0.001491,0.001476,0.001507,0.001469,0.001489,0.001479,0.001474,0.001477,0.001479,0.001494,0.001469,0.001485,0.001533,0.001496,0.00148,0.001509,0.001525,0.001474,0.001482,0.001522,0.001493,0.001472,0.001471,0.001511,0.001477,0.001489,0.001473,0.00155,0.001632,0.001494,0.001477,0.001472,0.001492,0.001473,0.001492,0.001481,0.001495,0.001484,0.00147,0.001501,0.00148,0.001482,0.00148,0.001492,0.001478,0.001506,0.001471,0.001477,0.00151,0.001472,0.001487,0.001476,0.001473,0.001474,0.001478,0.001491,0.001474,0.001487,0.001481,0.001573,0.00184,0.001532,0.001475,0.001473,0.00152,0.001482,0.001523,0.00147,0.00151,0.001479,0.001607,0.001618,0.001484,0.001542,0.001482,0.001504,0.001482,0.001512,0.001476,0.001472,0.001508,0.001478,0.001534,0.001472,0.001494,0.001532,0.001473,0.001472,0.001484,0.001492,0.001481,0.001482,0.001517,0.001583,0.001498,0.001478,0.001506,0.001482,0.001484,0.001486,0.001504,0.001481,0.001512,0.001473,0.001503,0.00151,0.001473,0.001488,0.001481,0.001518,0.001472,0.001472,0.001487,0.001482,0.001484,0.00148,0.001497,0.001482,0.00147,0.001489,0.00148,0.001493,0.001478,0.001491,0.001476,0.001477,0.002168,0.001944,0.001497,0.001472,0.001495,0.001483,0.001518,0.001486,0.001512,0.001486,0.001494,0.001475,0.001489,0.001512,0.001481,0.001486,0.001474,0.001496,0.001493,0.001473,0.001494,0.00148,0.001512,0.001471,0.001499,0.001491,0.001472,0.001471,0.00148,0.001488,0.001476,0.001487,0.001534,0.001826,0.001519,0.001599,0.001491,0.001471,0.001497,0.001475,0.001485,0.001484,0.001501,0.001475,0.001505,0.001496,0.001483,0.00149,0.001476,0.001496,0.001486,0.00148,0.00147,0.001477,0.001492,0.001515,0.0015,0.001479,0.00169,0.001722,0.001486,0.0015,0.001484,0.00151,0.001476,0.001506,0.001483,0.001974,0.001582,0.001521,0.001492,0.001483,0.00152,0.001475,0.001506,0.001485,0.001508,0.001478,0.001476,0.001484,0.001483,0.001515,0.001474,0.001496,0.001482,0.001476,0.001475,0.001482,0.001498,0.001476,0.002013,0.001509,0.001515,0.00187,0.001518,0.001479,0.001477,0.00148,0.001473,0.00151,0.00157,0.001505,0.001479,0.001579,0.001522,0.001475,0.001474,0.001479,0.001509,0.001477,0.001484,0.001486,0.001487,0.001476,0.001489,0.001514,0.001478,0.001516,0.001514,0.001504,0.001482,0.001477,0.001498,0.001638,0.001855,0.002161,0.00218,0.001843,0.001492,0.001557,0.001991,0.001782,0.0016,0.002421,0.002352,0.002346,0.002441,0.002383,0.002352,0.002382,0.002363,0.002343,0.002422,0.0024,0.002377,0.002387,0.002395,0.002381,0.002365,0.002428,0.002374,0.002381,0.002431,0.002351,0.002354,0.002387,0.002344,0.002388,0.002324,0.001489,0.001481,0.00158,0.001485,0.00154,0.001482,0.001512,0.001482,0.001537,0.001493,0.001478,0.001526,0.001483,0.001512,0.001487,0.001533,0.001484,0.001475,0.001476,0.001493,0.00153,0.00148,0.001506,0.001485,0.001503,0.00148,0.001474,0.001509,0.001479,0.001536,0.001479,0.001548,0.001498,0.001502,0.001495,0.001488,0.001514,0.001489,0.001515,0.001535,0.001526,0.001477,0.001478,0.001535,0.001483,0.001512,0.001483,0.001535,0.001487,0.001473,0.001475,0.001491,0.001516,0.001476,0.001527,0.0015,0.001628,0.001542,0.001493,0.001498,0.001491,0.00152,0.001484,0.001518,0.001504,0.001516,0.001508,0.001497,0.001528,0.001489,0.001522,0.001497,0.001513,0.001477,0.001493,0.001489,0.001492,0.001849,0.001492,0.001534,0.00149,0.001518,0.001493,0.001486,0.001481,0.001484,0.001548,0.001478,0.00152,0.00149,0.001518,0.001483,0.001552,0.001488,0.001482,0.001524,0.001489,0.001512,0.00149,0.00149,0.0015,0.001484,0.001532,0.00149,0.001515,0.001478,0.001516,0.00152,0.001482,0.001478,0.001545,0.00155,0.001515,0.001529,0.001513,0.001524,0.001496,0.001498,0.001487,0.001493,0.001538,0.001482,0.001524,0.001483,0.001525,0.001478,0.001479,0.00153,0.001507,0.001506,0.001478,0.001519,0.001481,0.001478,0.001493,0.001494,0.00153,0.001499,0.00153,0.001491,0.001518,0.001479,0.001742,0.001508,0.001487,0.001571,0.001484,0.001513,0.001478,0.001542,0.001487,0.001477,0.001478,0.001486,0.001521,0.00149,0.001519,0.001496,0.001527,0.001564,0.001481,0.001551,0.001489,0.001526,0.001492,0.00182,0.001483,0.001532,0.001508,0.00149,0.001478,0.001513,0.001511,0.001481,0.001545,0.001495,0.001526,0.001489,0.001482,0.001572,0.001547,0.001524,0.00148,0.001526,0.001726,0.00161,0.001488,0.001573,0.001577,0.001665,0.001633,0.001505,0.001526,0.001492,0.001985,0.002257,0.001647,0.001549,0.001512,0.00158,0.001539,0.001482,0.00151,0.001487,0.001611,0.001499,0.001485,0.001549,0.001504,0.001644,0.00151,0.00154,0.001482,0.001515,0.001488,0.001489,0.001486,0.001479,0.001506,0.001715,0.00154,0.001479,0.001505,0.001507,0.0016,0.001488,0.001535,0.001514,0.001485,0.001512,0.001488,0.001499,0.001504,0.001526,0.001497,0.001483,0.001504,0.001488,0.001495,0.001495,0.001502,0.00152,0.001497,0.001536,0.001498,0.001517,0.001492,0.001511,0.001488,0.001561,0.001505,0.00148,0.001511,0.001495,0.001503,0.001504,0.001551,0.001516,0.001485,0.001486,0.00148,0.001599,0.001495,0.001623,0.001497,0.001504,0.001486,0.001492,0.001495,0.001523,0.001684,0.001589,0.001532,0.001492,0.001503,0.001493,0.001494,0.001484,0.001476,0.001516,0.001772,0.001521,0.001498,0.001569,0.001496,0.001499,0.001504,0.001498,0.001503,0.001486,0.001509,0.001493,0.001503,0.001488,0.001488,0.001478,0.001503,0.001577,0.00152,0.001533,0.001482,0.001513,0.001501,0.001483,0.001508,0.001496,0.001495,0.001484,0.00151,0.001489,0.001488,0.001514,0.001488,0.001521,0.001479,0.00151,0.001494,0.001504,0.001491,0.00148,0.001538,0.001495,0.001717,0.00149,0.001543,0.001512,0.001526,0.001477,0.001608,0.001643,0.001499,0.001685,0.001594,0.00165,0.001559,0.001549,0.001498,0.001518,0.001492,0.001526,0.001501,0.001502,0.001628,0.001495,0.001526,0.001504,0.00151,0.00151,0.001614,0.001533,0.001503,0.001524,0.001504,0.0015,0.001525,0.001534,0.001487,0.001484,0.001507,0.001483,0.001717,0.001506,0.001653,0.001767,0.00177,0.001615,0.001569,0.001539,0.001532,0.001485,0.001503,0.00149,0.001545,0.001509,0.001483,0.001509,0.001489,0.001502,0.001485,0.001493,0.001506,0.001481,0.001511,0.00149,0.001505,0.001491,0.001495,0.001487,0.001489,0.001526,0.001485,0.001525,0.00149,0.001498,0.001494,0.001522,0.001493,0.001501,0.001501,0.001536,0.001505,0.001485,0.001497,0.001506,0.00149,0.0015,0.00148,0.001507,0.001503,0.001495,0.001481,0.001489,0.001485,0.001686,0.001527,0.001482,0.001505,0.001489,0.001496,0.001486,0.001493,0.001517,0.001484,0.001505,0.001533,0.001509,0.001486,0.00151,0.001489,0.001492,0.001501,0.001479,0.001513,0.001492,0.001501,0.001528,0.001527,0.001673,0.001488,0.001514,0.00148,0.001507,0.00149,0.001498,0.0015,0.001513,0.001493,0.001483,0.001512,0.001499,0.001507,0.001483,0.001526,0.001495,0.001487,0.001533,0.001486,0.001723,0.001492,0.001539,0.001486,0.001521,0.001492,0.00149,0.001521,0.001497,0.001505,0.001489,0.001498,0.00148,0.001496,0.001547,0.001481,0.001503,0.001491,0.001503,0.001489,0.001497,0.001506,0.001488,0.001506,0.001519,0.001554,0.001489,0.001509,0.001708,0.001507,0.001499,0.001496,0.001484,0.001483,0.001509,0.001492,0.001508,0.001501,0.001507,0.001492,0.001485,0.001505,0.001492,0.001506,0.001532,0.001503,0.001491,0.001496,0.001503,0.001486,0.001515,0.001539,0.001542,0.001487,0.001501,0.001503,0.001491,0.001484,0.001482,0.001545,0.001488,0.001527,0.001513,0.001551,0.001503,0.001486,0.001499,0.001497,0.001532,0.001487,0.001504,0.0015,0.00149,0.00149,0.001481,0.0015,0.001514,0.001509,0.001487,0.001516,0.001492,0.001528,0.001516,0.001485,0.00151,0.001491,0.001503,0.001539,0.001491,0.001488,0.001484,0.001499,0.001492,0.00151,0.001501,0.001515,0.001488,0.001491,0.001502,0.001481,0.001503,0.00149,0.001497,0.001484,0.001493,0.001557,0.001669,0.001518,0.001482,0.001535,0.001494,0.001537,0.001486,0.00149,0.001489,0.001484,0.001536,0.001489,0.001509,0.001487,0.001495,0.001501,0.001487,0.001509,0.001488,0.001515,0.001492,0.00153,0.001505,0.001501,0.001504,0.001501,0.0015,0.001496,0.001514,0.001489,0.0015,0.001494,0.001554,0.00153,0.001487,0.00151,0.001514,0.001511,0.001494,0.001515,0.001493,0.001567,0.001503,0.001489,0.00151,0.001506,0.0015,0.001486,0.001519,0.001495,0.001486,0.001506,0.001534,0.001506,0.001534,0.001508,0.001515,0.00149,0.001507,0.001491,0.001546,0.001498,0.001527,0.001489,0.001507,0.00149,0.001488,0.001518,0.001506,0.001508,0.001483,0.001502,0.001504,0.001496,0.0015,0.001484,0.001506,0.001492,0.001503,0.001501,0.001491,0.001493,0.001487,0.001536,0.001498,0.00157,0.001487,0.001525,0.001487,0.001515,0.001543,0.001487,0.001516,0.001505,0.001745,0.001498,0.001522,0.001503,0.001521,0.001504,0.001487,0.001525,0.001485,0.001511,0.001491,0.001508,0.001757,0.001519,0.001498,0.001493,0.001505,0.001489,0.001526,0.001495,0.001531,0.001486,0.001493,0.001555,0.001486,0.00151,0.001495,0.001512,0.001491,0.001526,0.001511,0.001495,0.001487,0.001618,0.001571,0.00153,0.001519,0.001502,0.001513,0.001497,0.001499,0.001506,0.001504,0.001509,0.001499,0.001518,0.001505,0.001511,0.001488,0.001492,0.001514,0.001493,0.001553,0.001485,0.00152,0.001491,0.001484,0.001493,0.001491,0.001508,0.001495,0.001497,0.001496,0.001503,0.001505,0.001487,0.001508,0.001502,0.001497,0.001601,0.001504,0.001492,0.001497,0.001491,0.001494,0.001519,0.001551,0.001503,0.001483,0.001512,0.001542,0.001491,0.001488,0.001497,0.001509,0.001489,0.00151,0.001509,0.001519,0.001492,0.001487,0.001508,0.001521,0.001503,0.001488,0.001508,0.00149,0.00149,0.001509,0.001501,0.001508,0.001484,0.00151,0.001525,0.001511,0.001764,0.001496,0.001486,0.001498,0.001526,0.001493,0.001512,0.001489,0.001503,0.001501,0.001486,0.001506,0.0015,0.001506,0.001758,0.001513,0.001489,0.00151,0.001505,0.00149,0.001488,0.0015,0.001508,0.001491,0.0015,0.001495,0.00152,0.001507,0.001491,0.001513,0.001491,0.001506,0.001549,0.001528,0.001497,0.001499,0.001491,0.001563,0.00154,0.001495,0.00151,0.001501,0.001506,0.001505,0.00149,0.001487,0.0015,0.001515,0.00149,0.001512,0.001512,0.001516,0.001496,0.001485,0.001507,0.001497,0.001501,0.001485,0.001528,0.001498,0.001503,0.001526,0.001497,0.00151,0.001489,0.001531,0.001518,0.00152,0.001492,0.001492,0.00151,0.001495,0.001513,0.001557,0.001511,0.001495,0.001491,0.001496,0.001486,0.001506,0.001492,0.001502,0.001499,0.00151,0.001498,0.001493,0.001527,0.001495,0.001512,0.001526,0.00151,0.001496,0.001503,0.001488,0.001495,0.001528,0.001494,0.001508,0.001486,0.001505,0.001504,0.001487,0.001509,0.001497,0.001503,0.001537,0.00152,0.00151,0.001508,0.001491,0.001488,0.001517,0.001492,0.001501,0.001494,0.001508,0.001493,0.001493,0.00151,0.001496,0.00152,0.001486,0.0015,0.001499,0.001508,0.001491,0.001494,0.001513,0.001494,0.001512,0.001488,0.001509,0.001491,0.001493,0.001492,0.001496,0.001507,0.0015,0.00153,0.001497,0.001514,0.001496,0.001488,0.001537,0.001498,0.001527,0.001562,0.001521,0.001496,0.001683,0.00149,0.001503,0.00154,0.001504,0.001504,0.001491,0.001511,0.001506,0.001505,0.001498,0.001509,0.001508,0.001506,0.001515,0.001499,0.00151,0.001487,0.001498,0.0015,0.001497,0.001525,0.001521,0.001504,0.001498,0.00151,0.001513,0.001523,0.001522,0.001499,0.001504,0.001492,0.001509,0.001494,0.001492,0.001873,0.001494,0.001512,0.001502,0.00151,0.001493,0.001505,0.001501,0.001514,0.001492,0.001489,0.001513,0.001499,0.001521,0.001491,0.001511,0.001499,0.001493,0.001491,0.001536,0.001512,0.00149,0.001513,0.001501,0.001512,0.001505,0.001493,0.001497,0.001496,0.001506,0.001507,0.00151,0.001542,0.001507,0.001496,0.001502,0.001578,0.001504,0.001511,0.001494,0.001508,0.001495,0.001488,0.001492,0.001499,0.001513,0.001493,0.001562,0.001502,0.001518,0.001494,0.001494,0.001515,0.001497,0.001507,0.001495,0.001516,0.0015,0.00151,0.001502,0.001502,0.001514,0.001492,0.001507,0.0015,0.001511,0.0015,0.00149,0.001499,0.001497,0.001519,0.001606,0.001691,0.001493,0.00153,0.001499,0.001542,0.001496,0.001498,0.00153,0.001769,0.001538,0.001497,0.001513,0.001499,0.001518,0.001508,0.001496,0.001516,0.001501,0.001507,0.001497,0.001517,0.00151,0.001494,0.001492,0.001498,0.001515,0.001495,0.001512,0.0015,0.001521,0.001495,0.001494,0.001541,0.001499,0.001518,0.001498,0.001675,0.001495,0.001522,0.001499,0.001493,0.001877,0.001495,0.00151,0.001499,0.001514,0.001491,0.001504,0.001507,0.001513,0.001493,0.00149,0.001511,0.001502,0.001515,0.001491,0.001514,0.001497,0.001492,0.001495,0.001536,0.001514,0.001497,0.001507,0.001498,0.001512,0.001506,0.001496,0.001515,0.001576,0.00155,0.001514,0.001508,0.001559,0.001518,0.001499,0.001512,0.001513,0.001508,0.001516,0.001495,0.001522,0.001505,0.001537,0.001494,0.001512,0.001516,0.001521,0.001535,0.001509,0.001522,0.001506,0.001498,0.001505,0.001493,0.001522,0.001506,0.001523,0.001497,0.001524,0.001517,0.001493,0.001533,0.001502,0.001591,0.001506,0.001509,0.001494,0.001596,0.001498,0.001504,0.001519,0.001493,0.001512,0.001504,0.00153,0.001507,0.001573,0.001495,0.001524,0.001521,0.001493,0.001542,0.001523,0.00153,0.001499,0.00151,0.001515,0.001501,0.0015,0.001498,0.001559,0.0015,0.001528,0.001493,0.001509,0.0015,0.001503,0.001529,0.001493,0.001526,0.0015,0.001508,0.001494,0.001517,0.001548,0.001501,0.001515,0.001493,0.001516,0.001527,0.001509,0.001498,0.001501,0.001502,0.001497,0.001526,0.001504,0.001522,0.001499,0.001507,0.001508,0.0015,0.001495,0.001501,0.00153,0.001503,0.00156,0.001495,0.001535,0.001506,0.001533,0.001494,0.001491,0.001551,0.001507,0.001513,0.001498,0.00151,0.001516,0.001501,0.001511,0.001492,0.001516,0.0016,0.002264,0.0024,0.001792,0.002057,0.002314,0.002084,0.00215,0.001547,0.00151,0.00153,0.001496,0.001556,0.001499,0.001549,0.001538,0.001558,0.001592,0.001514,0.00154,0.001497,0.001554,0.001506,0.001549,0.001497,0.001548,0.00152,0.001503,0.001499,0.001505,0.001606,0.00151,0.001568,0.001526,0.001559,0.001733,0.00173,0.001709,0.001647,0.001502,0.001579,0.001535,0.001504,0.00154,0.001496,0.001526,0.001505,0.001553,0.001514,0.001526,0.001521,0.001499,0.001581,0.001509,0.001539,0.001502,0.001536,0.001496,0.001528,0.001529,0.001503,0.001518,0.001495,0.001515,0.001506,0.001516,0.001496,0.001511,0.001549,0.001497,0.001566,0.001523,0.001534,0.001516,0.001525,0.0015,0.001502,0.001503,0.001501,0.001531,0.001504,0.001538,0.001498,0.001516,0.001503,0.001505,0.001543,0.001499,0.001574,0.001507,0.001522,0.001498,0.001515,0.001522,0.001517,0.001502,0.001499,0.001518,0.00151,0.001594,0.001496,0.001519,0.001507,0.002054,0.001543,0.001515,0.001517,0.001526,0.001543,0.001526,0.001518,0.001522,0.001524,0.001526,0.00151,0.001515,0.001499,0.001518,0.001506,0.001515,0.001571,0.001532,0.001506,0.001498,0.001647,0.001507,0.001563,0.001543,0.001521,0.001509,0.001519,0.001507,0.001512,0.001503,0.001514,0.001529,0.001508,0.001549,0.001508,0.001528,0.001508,0.001504,0.001503,0.001507,0.001532,0.0015,0.001524,0.001505,0.001522,0.00151,0.001501,0.001508,0.001501,0.001529,0.001502,0.001547,0.00151,0.00153,0.001496,0.001555,0.001521,0.001511,0.001526,0.001506,0.00152,0.001533,0.001534,0.001504,0.001501,0.001506,0.001505,0.001532,0.001501,0.001562,0.001515,0.001546,0.001499,0.001501,0.001508,0.001507,0.001538,0.001501,0.001537,0.001534,0.001708,0.00156,0.001549,0.0015,0.001497,0.001525,0.001504,0.001516,0.0015,0.001521,0.001517,0.001561,0.001502,0.00156,0.001529,0.001503,0.00151,0.0015,0.001518,0.001501,0.001498,0.001516,0.001508,0.001535,0.001498,0.001523,0.001509,0.001523,0.001537,0.001502,0.001498,0.001511,0.001546,0.001502,0.001511,0.001508,0.001519,0.001513,0.0015,0.001508,0.001504,0.001515,0.0015,0.001522,0.001518,0.001512,0.001505,0.001559,0.001551,0.001507,0.001516,0.001503,0.001529,0.001502,0.00153,0.001518,0.00155,0.001526,0.001504,0.001544,0.001503,0.001523,0.001503,0.001513,0.0015,0.001506,0.001539,0.001501,0.001516,0.001505,0.001526,0.0015,0.001504,0.001498,0.001505,0.001807,0.001504,0.001534,0.001502,0.001524,0.001507,0.001517,0.0015,0.001562,0.001752,0.001508,0.001533,0.0015,0.001518,0.001511,0.001523,0.001507,0.001499,0.001507,0.001521,0.001513,0.001507,0.001526,0.001506,0.001518,0.001519,0.0015,0.001525,0.00151,0.00152,0.001499,0.001549,0.00153,0.001519,0.001687,0.0015,0.001524,0.001546,0.001532,0.001502,0.001611,0.001512,0.001532,0.001512,0.001552,0.0015,0.001507,0.001563,0.001502,0.001524,0.001503,0.001527,0.001512,0.001505,0.001501,0.001517,0.001525,0.001499,0.001517,0.001507,0.001526,0.001502,0.001498,0.001514,0.001506,0.001558,0.001555,0.001528,0.001507,0.001524,0.001514,0.0015,0.001508,0.001507,0.001518,0.00152,0.001519,0.00151,0.001517,0.001505,0.001545,0.001524,0.001506,0.001515,0.0015,0.001518,0.001514,0.001521,0.001504,0.0015,0.001547,0.001506,0.001542,0.001502,0.001555,0.001508,0.001523,0.001502,0.001498,0.001527,0.001512,0.001519,0.001501,0.001521,0.001521,0.001517,0.001508,0.001513,0.001523,0.001505,0.00152,0.00151,0.001526,0.001499,0.001507,0.001514,0.001551,0.001525,0.001502,0.001517,0.001514,0.001522,0.001528,0.001508,0.001511,0.001508,0.001537,0.001511,0.001521,0.001784,0.001534,0.001532,0.001515,0.001519,0.00151,0.001525,0.001516,0.001534,0.001506,0.001527,0.001508,0.001514,0.001506,0.001692,0.002231,0.002063,0.001526,0.001544,0.001555,0.001534,0.001507,0.001859,0.002234,0.001943,0.00153,0.00152,0.001536,0.001502,0.001542,0.001507,0.00152,0.001504,0.001529,0.001508,0.001531,0.001599,0.001509,0.00151,0.001506,0.001551,0.001511,0.001532,0.001508,0.001517,0.001506,0.001509,0.001552,0.001504,0.001528,0.001514,0.001528,0.001508,0.001536,0.00152,0.00151,0.001512,0.001508,0.001521,0.001519,0.001529,0.001504,0.001523,0.001523,0.001515,0.001509,0.001506,0.001519,0.001514,0.001557,0.001556,0.001525,0.001506,0.001547,0.001523,0.001507,0.001548,0.001511,0.001522,0.001511,0.001529,0.001521,0.001512,0.001509,0.001504,0.001528,0.001513,0.001525,0.001504,0.001519,0.001515,0.001508,0.00151,0.001503,0.001516,0.001511,0.001529,0.001518,0.001515,0.001509,0.001509,0.001529,0.001502,0.001526,0.001538,0.001524,0.001545,0.001526,0.001525,0.001509,0.001543,0.001532,0.001529,0.00152,0.001524,0.001505,0.001514,0.001511,0.001578,0.001697,0.001508,0.001524,0.001626,0.001526,0.001513,0.001518,0.001531,0.001509,0.001508,0.001516,0.00153,0.001511,0.001583,0.001509,0.00152,0.001506,0.001512,0.001507,0.001502,0.001528,0.001514,0.001528,0.001557,0.001522,0.001502,0.001511,0.001526,0.001505,0.001525,0.001509,0.001551,0.001504,0.001527,0.001526,0.001544,0.00152,0.001506,0.00152,0.001514,0.00153,0.001543,0.001521,0.001513,0.001512,0.001524,0.001508,0.001619,0.001869,0.00155,0.001524,0.001525,0.001507,0.001518,0.001512,0.001515,0.001526,0.001516,0.001525,0.001563,0.001531,0.001519,0.001521,0.001517,0.001516,0.001509,0.001506,0.002304,0.002246,0.001548,0.001537,0.001515,0.001528,0.001519,0.001503,0.001532,0.001512,0.001521,0.001523,0.001519,0.00151,0.00151,0.001519,0.001507,0.001529,0.001511,0.001525,0.001508,0.001518,0.001525,0.001508,0.001521,0.001513,0.001523,0.001643,0.001572,0.001524,0.00153,0.001512,0.001512,0.001549,0.001516,0.001522,0.001505,0.001531,0.001524,0.001541,0.001507,0.001506,0.001527,0.001513,0.001539,0.001507,0.001536,0.001566,0.00153,0.001508,0.001506,0.001525,0.001515,0.001529,0.001507,0.001523,0.001534,0.001555,0.001513,0.001506,0.001529,0.001514,0.001523,0.001509,0.001531,0.001511,0.001529,0.001518,0.001507,0.001525,0.001511,0.001523,0.001583,0.001529,0.001515,0.00153,0.001509,0.001512,0.001543,0.001515,0.001523,0.001507,0.00153,0.001512,0.001535,0.001506,0.001847,0.002226,0.001988,0.001584,0.001553,0.00155,0.001522,0.00151,0.001513,0.001529,0.00151,0.00152,0.001631,0.001605,0.001513,0.001566,0.001523,0.001508,0.001533,0.001561,0.001545,0.001517,0.00153,0.001508,0.001532,0.001541,0.001538,0.001525,0.001506,0.001532,0.001521,0.001567,0.001514,0.001527,0.00152,0.001532,0.00152,0.00151,0.00154,0.00153,0.00154,0.001516,0.001523,0.001524,0.001532,0.001516,0.001533,0.001715,0.001521,0.001547,0.001511,0.001523,0.001516,0.001531,0.001514,0.001506,0.00151,0.001512,0.001542,0.001507,0.001519,0.001513,0.001525,0.001525,0.001841,0.001511,0.001509,0.00153,0.001514,0.001539,0.001516,0.001532,0.001519,0.001574,0.00151,0.00151,0.001536,0.001516,0.001523,0.001514,0.001523,0.001529,0.001554,0.001558,0.001512,0.001514,0.001512,0.001531,0.001506,0.001524,0.001513,0.001527,0.001526,0.001509,0.00154,0.001542,0.001522,0.001511,0.001518,0.001514,0.001569,0.001505,0.00151,0.001538,0.001511,0.001519,0.001511,0.001527,0.001568,0.002236,0.002195,0.001561,0.001525,0.001541,0.001566,0.001534,0.001514,0.001508,0.001607,0.001511,0.001532,0.001513,0.001522,0.001506,0.001534,0.001532,0.001527,0.00151,0.001512,0.001526,0.001515,0.001524,0.00151,0.00153,0.001516,0.001592,0.001522,0.00151,0.001541,0.001514,0.001519,0.001515,0.001531,0.001516,0.001519,0.001509,0.001511,0.001572,0.001532,0.001536,0.001507,0.001521,0.001519,0.001531,0.001508,0.001507,0.001529,0.001518,0.001543,0.001509,0.001526,0.001515,0.001529,0.001512,0.001508,0.001523,0.001538,0.001542,0.001517,0.001562,0.001539,0.001534,0.001533,0.001551,0.001527,0.001525,0.001676,0.001537,0.001569,0.001558,0.001656,0.00163,0.001568,0.001542,0.001764,0.00172,0.001833,0.001676,0.001655,0.001517,0.001558,0.001536,0.00159,0.001518,0.001521,0.001529,0.001522,0.001541,0.001517,0.00154,0.001521,0.001535,0.001525,0.001518,0.001517,0.001517,0.001562,0.001519,0.001534,0.001517,0.001527,0.001555,0.001612,0.001534,0.001514,0.001551,0.001512,0.001534,0.001519,0.001523,0.00151,0.001529,0.001514,0.001516,0.001539,0.00151,0.001585,0.001515,0.001525,0.001522,0.001528,0.001516,0.001518,0.001525,0.001512,0.001571,0.001516,0.001526,0.001514,0.001527,0.00152,0.001513,0.00154,0.001508,0.001578,0.001519,0.001591,0.001543,0.001535,0.001518,0.001518,0.001525,0.001788,0.001536,0.001509,0.001559,0.001519,0.001535,0.001535,0.001519,0.001517,0.001515,0.001573,0.001509,0.001535,0.001517,0.001531,0.001511,0.001564,0.001532,0.001516,0.001526,0.001508,0.00155,0.001518,0.001536,0.001524,0.001618,0.001765,0.001552,0.001537,0.001517,0.001555,0.001955,0.001853,0.002175,0.002248,0.001634,0.001519,0.001556,0.002126,0.002253,0.001578,0.00157,0.001517,0.001596,0.001511,0.001576,0.001711,0.001565,0.001537,0.001522,0.001574,0.001548,0.002214,0.002341,0.002421,0.001824,0.00152,0.001599,0.002242,0.002167,0.001544,0.001551,0.001556,0.001549,0.001518,0.001562,0.001792,0.001551,0.001566,0.001547,0.001516,0.001603,0.002157,0.001553,0.001517,0.002192,0.002231,0.001605,0.001524,0.001547,0.001509,0.001517,0.001533,0.001745,0.001537,0.001509,0.001561,0.001517,0.001705,0.002388,0.002433,0.002452,0.002379,0.002672,0.002476,0.002713,0.00177,0.001988,0.001628,0.001872,0.00168,0.001577,0.001684,0.001557,0.001513,0.001666,0.002054,0.001561,0.001515,0.001559,0.001536,0.001522,0.001787,0.001528,0.001602,0.002269,0.001865,0.001616,0.002441,0.002671,0.002414,0.002421,0.002431,0.002464,0.00242,0.002378,0.002416,0.002407,0.002391,0.002404,0.002337,0.002474,0.002467,0.002443,0.002431,0.002209,0.002063,0.002069,0.00154,0.002122,0.002444,0.002396,0.002423,0.002432,0.002443,0.002406,0.00247,0.00247,0.002376,0.00243,0.002397,0.002383,0.002412,0.002429,0.002386,0.002373,0.002175,0.001516,0.001547,0.001521,0.001523,0.001517,0.001516,0.001598,0.00152,0.001544,0.001517,0.001529,0.001657,0.002408,0.002405,0.002369,0.002411,0.002386,0.002499,0.002524,0.002706,0.002397,0.002481,0.002464,0.002497,0.002395,0.002465,0.002431,0.002377,0.002475,0.00191,0.00167,0.002406,0.002415,0.002404,0.002053,0.001525,0.001554,0.001513,0.001528,0.001538,0.001541,0.001557,0.001512,0.001554,0.001524,0.00155,0.001517,0.001627,0.001525,0.00163,0.001646,0.001519,0.001555,0.001513,0.001562,0.001972,0.002434,0.002468,0.002429,0.002446,0.002486,0.002383,0.002402,0.002429,0.002422,0.00237,0.002451,0.002546,0.0024,0.002491,0.00244,0.002395,0.002515,0.002477,0.002159,0.001571,0.002208,0.002391,0.002474,0.002393,0.002415,0.001924,0.001512,0.001555,0.001521,0.001534,0.001516,0.001514,0.001567,0.001526,0.00154,0.001521,0.001535,0.001515,0.001541,0.00152,0.001599,0.001612,0.002415,0.002395,0.002483,0.002478,0.002411,0.002361,0.002441,0.002395,0.00232,0.002383,0.002407,0.002486,0.002381,0.002365,0.002387,0.001538,0.001513,0.001537,0.001521,0.001552,0.001538,0.001829,0.001516,0.001517,0.001545,0.001522,0.001529,0.001517,0.001615,0.001724,0.001996,0.001513,0.001557,0.001522,0.001688,0.002288,0.002341,0.001586,0.002222,0.002452,0.002396,0.002414,0.002474,0.002389,0.002406,0.002474,0.002401,0.002387,0.002315,0.002485,0.002426,0.002571,0.002424,0.002493,0.002486,0.002379,0.002403,0.002468,0.002311,0.001679,0.002441,0.002451,0.002408,0.001739,0.001523,0.00157,0.001531,0.001556,0.001518,0.001549,0.001872,0.001569,0.001543,0.00152,0.001559,0.001518,0.001563,0.001523,0.001542,0.001516,0.001554,0.001525,0.001524,0.001549,0.001532,0.00154,0.001524,0.001542,0.001859,0.002491,0.002421,0.002405,0.002427,0.002461,0.002358,0.002425,0.002313,0.002426,0.002439,0.002415,0.002496,0.002374,0.00242,0.00236,0.002369,0.002399,0.002452,0.002402,0.00246,0.002364,0.002437,0.002447,0.002282,0.001519,0.001523,0.00154,0.001519,0.001554,0.001664,0.001567,0.001695,0.001588,0.001525,0.001558,0.00154,0.001558,0.001543,0.001527,0.001576,0.001516,0.00156,0.002226,0.002325,0.00237,0.002339,0.002482,0.002424,0.002081,0.002112,0.001526,0.002081,0.002398,0.002402,0.002375,0.00247,0.002403,0.002418,0.00235,0.002408,0.00153,0.001528,0.002333,0.001978,0.001521,0.001565,0.001568,0.001566,0.001528,0.001525,0.001605,0.001519,0.001584,0.001528,0.001577,0.001517,0.001554,0.001522,0.001522,0.001523,0.001516,0.001537,0.001557,0.001548,0.001532,0.001939,0.001525,0.001552,0.001717,0.002366,0.002336,0.002348,0.002384,0.002372,0.002354,0.002369,0.00245,0.002483,0.002397,0.002514,0.002401,0.002404,0.002386,0.002401,0.002431,0.002387,0.002409,0.001704,0.001535,0.001569,0.001524,0.001557,0.001522,0.001538,0.001527,0.001525,0.001516,0.001519,0.001559,0.001527,0.001662,0.001695,0.001636,0.002276,0.002178,0.001548,0.001549,0.001578,0.001565,0.001525,0.001571,0.001517,0.001534,0.001626,0.00236,0.002407,0.002405,0.002335,0.002415,0.002394,0.002398,0.002399,0.002437,0.002434,0.002363,0.002396,0.002354,0.00247,0.002458,0.00238,0.002483,0.002507,0.002523,0.002542,0.002499,0.002555,0.001711,0.00152,0.001567,0.00153,0.001562,0.001539,0.001554,0.00157,0.001533,0.00162,0.001583,0.001558,0.001521,0.001558,0.001523,0.001536,0.001534,0.001562,0.001525,0.001524,0.001536,0.002327,0.002596,0.002439,0.002677,0.002443,0.002712,0.002522,0.002552,0.002411,0.002486,0.00242,0.002403,0.00255,0.002685,0.002485,0.001526,0.001555,0.001579,0.001518,0.001611,0.001531,0.001569,0.001525,0.001549,0.001525,0.001525,0.001523,0.00152,0.001541,0.001555,0.001559,0.001525,0.001531,0.001523,0.001539,0.001655,0.001526,0.00152,0.001523,0.001541,0.001524,0.001554,0.00152,0.001538,0.001527,0.001524,0.001528,0.002446,0.002471,0.002492,0.002552,0.002496,0.002503,0.002505,0.002508,0.002477,0.002454,0.002555,0.002474,0.001804,0.001521,0.001605,0.001532,0.001562,0.001576,0.001569,0.001526,0.001546,0.00154,0.001525,0.001553,0.001518,0.00154,0.001531,0.001541,0.001537,0.001592,0.001533,0.00153,0.001537,0.001521,0.001539,0.00167,0.001555,0.001532,0.001561,0.001518,0.001534,0.001527,0.001531,0.001548,0.00152,0.001545,0.001523,0.001539,0.00187,0.002505,0.002484,0.002526,0.002539,0.002477,0.002405,0.002431,0.002404,0.002458,0.002465,0.002443,0.002481,0.002433,0.002478,0.002332,0.001522,0.001526,0.001528,0.001525,0.001578,0.001518,0.001566,0.001527,0.001536,0.001523,0.001541,0.001533,0.001794,0.001693,0.001712,0.001712,0.00171,0.001686,0.001699,0.001696,0.001743,0.001698,0.001692,0.001693,0.00171,0.001726,0.001697,0.00173,0.002344,0.002633,0.002595,0.002617,0.002588,0.002657,0.002694,0.002715,0.00266,0.002868,0.002785,0.002645,0.002597,0.002226,0.001702,0.00172,0.001695,0.001729,0.001693,0.001692,0.001705,0.001701,0.001709,0.001694,0.001709,0.001686,0.001718,0.001694,0.001707,0.001695,0.001697,0.001688,0.001686,0.001711,0.001694,0.001711,0.001739,0.001618,0.001545,0.001587,0.001697,0.002408,0.002477,0.001543,0.001541,0.001602,0.001545,0.001633,0.001528,0.00205,0.001798,0.001566,0.001523,0.00156,0.001533,0.001566,0.001559,0.001535,0.001711,0.00154,0.00153,0.001553,0.001578,0.001529,0.001555,0.00154,0.001597,0.001582,0.001549,0.001633,0.001526,0.002408,0.002379,0.002373,0.002279,0.002336,0.002284,0.002409,0.002425,0.00236,0.001567,0.001531,0.001564,0.001529,0.001652,0.001548,0.001574,0.001778,0.001553,0.001542,0.001559,0.001525,0.001884,0.002491,0.002712,0.002412,0.002447,0.002626,0.002484,0.002432,0.002478,0.00248,0.002587,0.002442,0.002657,0.002449,0.002561,0.002465,0.002586,0.00213,0.001532,0.001575,0.00196,0.002534,0.002499,0.002593,0.001994,0.002316,0.002597,0.002525,0.002455,0.002457,0.002527,0.002506,0.002512,0.001993,0.001567,0.002119,0.002533,0.002555,0.0025,0.002396,0.002371,0.002149,0.001581,0.001759,0.002554,0.002469,0.002467,0.002136,0.001531,0.001531,0.001522,0.001567,0.001566,0.001835,0.001553,0.001567,0.00154,0.001583,0.001563,0.002086,0.002702,0.00247,0.002505,0.002462,0.002457,0.002448,0.002416,0.002462,0.002529,0.002496,0.002452,0.002329,0.002572,0.002459,0.002449,0.0025,0.002288,0.002092,0.001865,0.001529,0.001595,0.002299,0.002032,0.001543,0.001576,0.001575,0.001565,0.001524,0.001566,0.001822,0.001596,0.001548,0.001536,0.001564,0.001653,0.002598,0.0028,0.00241,0.002446,0.002524,0.002231,0.001538,0.001564,0.00156,0.001547,0.001528,0.001878,0.001546,0.001635,0.001602,0.001531,0.001719,0.002497,0.002735,0.002241,0.001652,0.001601,0.001548,0.001626,0.001529,0.001568,0.001584,0.001585,0.001549,0.001559,0.001603,0.001663,0.00159,0.001836,0.002449,0.002476,0.002457,0.002445,0.002437,0.002233,0.001781,0.001832,0.002644,0.002562,0.002434,0.00244,0.00245,0.002461,0.002421,0.002247,0.002104,0.001806,0.002004,0.002297,0.002243,0.001577,0.00158,0.001597,0.002312,0.002175,0.001568,0.001554,0.001555,0.002378,0.002455,0.00231,0.002613,0.002387,0.00254,0.002403,0.002544,0.002404,0.002387,0.002471,0.004169,0.002468,0.002618,0.003679,0.002618,0.002399,0.002981,0.002599,0.002119,0.001613,0.002111,0.002534,0.002805,0.002402,0.002533,0.002479,0.002678,0.002388,0.002388,0.002553,0.002398,0.00241,0.002457,0.002379,0.002501,0.002674,0.002641,0.002536,0.002406,0.001877,0.002405,0.002741,0.002566,0.002433,0.002537,0.00247,0.002436,0.002413,0.002607,0.00262,0.002596,0.002451,0.002371,0.002473,0.002444,0.002469,0.002461,0.002428,0.001886,0.002325,0.002417,0.00279,0.002398,0.002439,0.002438,0.002468,0.002427,0.002386,0.002426,0.002421,0.002417,0.002435,0.002357,0.002508,0.002449,0.002471,0.002438,0.002406,0.002119,0.00253,0.002327,0.002234,0.002185,0.002422,0.002315,0.002662,0.002698,0.002736,0.00272,0.002734,0.002725,0.002731,0.00258,0.002404,0.002472,0.002475,0.002407,0.002405,0.002384,0.002343,0.002366,0.002448,0.002642,0.002685,0.002574,0.002354,0.002043,0.002406,0.002258,0.00217,0.002325,0.002516,0.001582,0.002285,0.002274,0.001609,0.00159,0.001553,0.001571,0.00153,0.001549,0.001836,0.001529,0.001579,0.001538,0.001592,0.001689,0.001961,0.001574,0.001648,0.001586,0.00181,0.001718,0.001745,0.001531,0.001566,0.001534,0.001572,0.001613,0.001955,0.001532,0.001523,0.001534,0.001537,0.002225,0.002502,0.00159,0.001703,0.002347,0.002037,0.001575,0.001565,0.001564,0.002071,0.001598,0.001635,0.002116,0.00162,0.001685,0.001799,0.001649,0.001804,0.002428,0.002347,0.002392,0.002282,0.00159,0.001588,0.001558,0.001567,0.001532,0.001583,0.001841,0.001592,0.001531,0.00154,0.001588,0.00184,0.00239,0.002732,0.002504,0.00243,0.002467,0.002477,0.002415,0.002418,0.002439,0.002434,0.002427,0.002439,0.002348,0.001754,0.001536,0.001571,0.00153,0.001557,0.00158,0.002435,0.002682,0.002624,0.002394,0.002467,0.002455,0.00246,0.00245,0.002394,0.002418,0.002457,0.002452,0.001641,0.001784,0.001529,0.001595,0.001539,0.001534,0.001877,0.002059,0.001788,0.001572,0.00218,0.00231,0.001595,0.001575,0.001532,0.001571,0.001536,0.00167,0.001849,0.001574,0.001538,0.001537,0.001598,0.001715,0.002361,0.001567,0.001676,0.002282,0.002033,0.001582,0.001549,0.001583,0.001719,0.001611,0.001557,0.001927,0.001539,0.001596,0.001551,0.001551,0.001839,0.002381,0.002708,0.002492,0.002488,0.002502,0.002468,0.002441,0.00244,0.002444,0.002426,0.002467,0.002411,0.002436,0.002461,0.002495,0.002471,0.002501,0.002425,0.001614,0.001535,0.001542,0.00155,0.00157,0.001591,0.001635,0.001536,0.001942,0.00246,0.002443,0.002501,0.002483,0.002314,0.001797,0.001536,0.00188,0.00222,0.002264,0.002373,0.001659,0.001825,0.001541,0.001571,0.001623,0.001567,0.001528,0.001539,0.00221,0.002448,0.001989,0.00234,0.002599,0.002453,0.002415,0.002488,0.002572,0.002745,0.002753,0.002753,0.002636,0.002453,0.002438,0.002429,0.002422,0.002441,0.002441,0.002439,0.002513,0.00274,0.002568,0.002583,0.002564,0.002529,0.002498,0.002301,0.002699,0.002565,0.001748,0.00154,0.001755,0.002276,0.002016,0.001548,0.001566,0.001545,0.00158,0.001577,0.001645,0.00177,0.001544,0.001566,0.001559,0.001625,0.001807,0.002332,0.001606,0.001563,0.001603,0.001543,0.001544,0.001698,0.00163,0.001654,0.0016,0.001634,0.001557,0.001624,0.00185,0.001568,0.001593,0.001601,0.001554,0.001643,0.002142,0.001571,0.001575,0.002215,0.002261,0.001643,0.001553,0.00158,0.001535,0.001573,0.001559,0.001819,0.001642,0.001572,0.001555,0.001566,0.001565,0.001605,0.002165,0.001535,0.001532,0.001587,0.001578,0.001543,0.00159,0.001534,0.001574,0.00155,0.001602,0.001591,0.001598,0.001705,0.001528,0.001537,0.001577,0.001586,0.001895,0.001856,0.001542,0.001938,0.002285,0.001855,0.001599,0.001537,0.001554,0.00155,0.001539,0.001791,0.001543,0.00157,0.001535,0.00157,0.001702,0.00246,0.001856,0.00159,0.00178,0.002289,0.002003,0.001557,0.001574,0.001594,0.00156,0.001545,0.001571,0.0018,0.001564,0.001581,0.001535,0.001581,0.002447,0.00188,0.00155,0.001583,0.00154,0.001607,0.001533,0.00157,0.001543,0.001582,0.001542,0.001539,0.001555,0.001541,0.001579,0.001539,0.001584,0.001546,0.001568,0.001542,0.001575,0.001578,0.001543,0.001558,0.001533,0.00162,0.001543,0.0016,0.001538,0.001555,0.001539,0.001584,0.001542,0.001534,0.001533,0.001572,0.001587,0.001545,0.001572,0.001544,0.001557,0.001542,0.001581,0.001541,0.001535,0.001544,0.001543,0.001557,0.001551,0.001562,0.001536,0.001593,0.001545,0.001558,0.001546,0.001537,0.001538,0.001542,0.001567,0.001546,0.001567,0.00153,0.001587,0.001542,0.001559,0.001536,0.00155,0.001534,0.001549,0.001556,0.00154,0.001552,0.001539,0.001562,0.001539,0.001551,0.001539,0.001533,0.001555,0.001543,0.001556,0.001538,0.001628,0.001535,0.001559,0.001541,0.001559,0.001546,0.001533,0.001564,0.00154,0.001558,0.001539,0.001549,0.001542,0.001576,0.00159,0.001535,0.001548,0.001542,0.001592,0.001548,0.001595,0.001539,0.001578,0.001547,0.001596,0.001543,0.001558,0.00154,0.001539,0.001592,0.00155,0.001588,0.001536,0.001558,0.001542,0.001614,0.001542,0.001597,0.001536,0.001534,0.001565,0.001541,0.001585,0.001535,0.00155,0.001536,0.001558,0.001543,0.001547,0.001581,0.001579,0.001543,0.001572,0.001555,0.001533,0.001575,0.001857,0.001558,0.00155,0.001561,0.001542,0.001565,0.001548,0.001534,0.001559,0.001541,0.00157,0.001545,0.00155,0.001543,0.001555,0.001541,0.001653,0.002283,0.002206,0.001564,0.00157,0.001581,0.001581,0.001543,0.001569,0.001543,0.001532,0.001606,0.001542,0.001557,0.001551,0.00156,0.001539,0.001682,0.0016,0.001572,0.001542,0.001536,0.001537,0.001544,0.001568,0.001543,0.001587,0.001545,0.001556,0.001553,0.001559,0.001551,0.001536,0.001535,0.001581,0.001558,0.001545,0.00157,0.001536,0.001558,0.001542,0.001556,0.001544,0.00154,0.001541,0.001551,0.001606,0.001548,0.001573,0.001536,0.001562,0.001543,0.001561,0.00155,0.001599,0.001684,0.001641,0.001674,0.001689,0.001688,0.001664,0.001744,0.001675,0.00168,0.001662,0.001657,0.001542,0.001552,0.001535,0.001561,0.001546,0.001572,0.001549,0.001536,0.001537,0.001544,0.001559,0.001541,0.00155,0.001538,0.001592,0.001622,0.00157,0.001549,0.001537,0.001537,0.001566,0.001574,0.001572,0.001563,0.001548,0.00155,0.001547,0.001562,0.00154,0.001539,0.001545,0.001545,0.001556,0.001549,0.001583,0.001541,0.001566,0.001558,0.001557,0.001542,0.001589,0.001545,0.001551,0.001565,0.001545,0.001558,0.001535,0.001565,0.001545,0.001557,0.00157,0.001572,0.00154,0.001546,0.001584,0.00154,0.001554,0.00154,0.001552,0.001548,0.001565,0.001544,0.00154,0.001542,0.001641,0.001566,0.001548,0.001575,0.00154,0.001556,0.001547,0.001568,0.001618,0.001597,0.001559,0.001545,0.001552,0.001591,0.001565,0.00155,0.001573,0.001546,0.001609,0.001551,0.001585,0.001543,0.001541,0.00154,0.001555,0.001586,0.001553,0.001594,0.001535,0.001582,0.001551,0.001565,0.001544,0.001536,0.001537,0.001545,0.00158,0.001544,0.001571,0.001539,0.001588,0.001548,0.001563,0.001591,0.001538,0.001539,0.001545,0.001577,0.001553,0.001578,0.001541,0.001559,0.001552,0.001566,0.001549,0.001555,0.00154,0.001542,0.001564,0.001547,0.001574,0.001536,0.001556,0.001545,0.001557,0.001542,0.00161,0.001553,0.00157,0.001564,0.001542,0.001577,0.001538,0.001554,0.001581,0.001585,0.001549,0.001556,0.001583,0.001538,0.001562,0.001544,0.001588,0.001538,0.001557,0.001548,0.00156,0.001545,0.001536,0.001544,0.001548,0.001562,0.001543,0.001562,0.001538,0.001578,0.001608,0.00156,0.001563,0.00154,0.00154,0.001547,0.001568,0.001552,0.00157,0.001539,0.001583,0.001552,0.001568,0.001544,0.001538,0.00154,0.001548,0.001604,0.001543,0.001592,0.001543,0.001559,0.001545,0.001557,0.00155,0.001538,0.00154,0.001583,0.001563,0.00155,0.00157,0.001536,0.001561,0.001545,0.001562,0.001541,0.001546,0.001541,0.001547,0.001586,0.001548,0.001577,0.001689,0.001561,0.00155,0.001558,0.001547,0.001555,0.001542,0.001545,0.00158,0.00155,0.001632,0.001539,0.001582,0.001581,0.001576,0.001561,0.00159,0.00154,0.001542,0.00154,0.001549,0.001603,0.001544,0.001557,0.001545,0.001749,0.001563,0.001568,0.001548,0.001582,0.001657,0.001663,0.001623,0.001602,0.001552,0.001554,0.001612,0.001542,0.001604,0.001552,0.001602,0.001552,0.001651,0.001568,0.001572,0.001598,0.001577,0.001649,0.001639,0.001642,0.001598,0.001679,0.001559,0.001654,0.001568,0.001656,0.001549,0.001633,0.001597,0.001573,0.00155,0.001595,0.001604,0.00182,0.001556,0.00155,0.001609,0.001548,0.001595,0.001598,0.001576,0.001541,0.001592,0.001555,0.001566,0.001558,0.001615,0.001541,0.00154,0.001565,0.001554,0.001584,0.00154,0.001595,0.001575,0.001576,0.001562,0.001577,0.001543,0.001541,0.001595,0.001548,0.001611,0.001595,0.001641,0.001542,0.00156,0.001601,0.001566,0.001552,0.001568,0.001584,0.001542,0.001563,0.001549,0.001559,0.001541,0.001556,0.00155,0.001578,0.001546,0.001553,0.001587,0.001545,0.001572,0.001547,0.001578,0.001541,0.001571,0.001552,0.001671,0.001577,0.001571,0.001598,0.001549,0.00156,0.001549,0.00161,0.001548,0.001576,0.001542,0.001555,0.001559,0.001562,0.001556,0.001545,0.00154,0.001555,0.001571,0.001551,0.0016,0.001549,0.001615,0.00156,0.001577,0.001547,0.001669,0.001553,0.001545,0.001561,0.001557,0.001579,0.001539,0.001558,0.001541,0.001567,0.001664,0.001581,0.001546,0.001551,0.001552,0.001555,0.001585,0.001567,0.001613,0.001574,0.001679,0.00155,0.001756,0.001563,0.001617,0.001592,0.0016,0.001569,0.001555,0.001574,0.001596,0.001605,0.001544,0.001585,0.001578,0.001681,0.001561,0.001564,0.001651,0.001565,0.001567,0.001619,0.001562,0.001567,0.001554,0.001543,0.001787,0.001559,0.001597,0.0016,0.001679,0.001551,0.001569,0.001554,0.001644,0.001547,0.001565,0.001614,0.001569,0.001571,0.001545,0.001644,0.001698,0.00168,0.001544,0.001592,0.00156,0.001567,0.001579,0.001561,0.001562,0.001572,0.001552,0.001547,0.001567,0.001544,0.001632,0.001785,0.001599,0.001571,0.001695,0.001561,0.001602,0.001586,0.001599,0.001568,0.001583,0.001566,0.00156,0.001676,0.001551,0.001591,0.001551,0.001586,0.001554,0.001574,0.001557,0.001559,0.001604,0.001568,0.001569,0.001552,0.001561,0.001557,0.001559,0.001568,0.001589,0.00155,0.001592,0.001603,0.001579,0.001581,0.001555,0.001573,0.001546,0.001612,0.001544,0.001579,0.001554,0.001569,0.001547,0.001574,0.001555,0.001574,0.001565,0.001554,0.001576,0.001546,0.001568,0.001552,0.001574,0.001562,0.001563,0.001601,0.001626,0.001591,0.001559,0.001553,0.001608,0.001579,0.001543,0.001592,0.001553,0.001578,0.001545,0.001563,0.001572,0.001575,0.001563,0.00156,0.001617,0.001545,0.001582,0.001555,0.001567,0.001551,0.001603,0.001576,0.001569,0.001554,0.001552,0.001553,0.001542,0.001587,0.001543,0.001612,0.00155,0.001574,0.001586,0.001564,0.001545,0.001561,0.001555,0.00155,0.001559,0.001552,0.001592,0.001551,0.001568,0.001655,0.001661,0.001557,0.001574,0.001573,0.001663,0.001858,0.001639,0.001557,0.001556,0.001578,0.00155,0.001595,0.001602,0.001599,0.001657,0.001685,0.001876,0.001571,0.001867,0.001611,0.001801,0.001689,0.00157,0.001634,0.001568,0.001582,0.001555,0.00184,0.001547,0.001574,0.00158,0.001802,0.001643,0.001575,0.001562,0.001751,0.001706,0.001706,0.001674,0.001656,0.001597,0.001549,0.001559,0.00178,0.00156,0.001571,0.001772,0.001668,0.001567,0.001549,0.001566,0.001556,0.001582,0.001555,0.00155,0.001563,0.001547,0.00168,0.001602,0.001608,0.00158,0.001567,0.001544,0.00156,0.001544,0.001593,0.001563,0.001558,0.001577,0.001554,0.001577,0.001602,0.001574,0.001561,0.001569,0.001549,0.001634,0.001586,0.001591,0.001552,0.001557,0.001739,0.00194,0.001567,0.001561,0.001609,0.001555,0.002268,0.002331,0.001761,0.001589,0.001586,0.001623,0.001567,0.001556,0.001561,0.001559,0.001566,0.001551,0.001562,0.001587,0.00157,0.001552,0.001571,0.001856,0.002201,0.002274,0.00162,0.001574,0.001621,0.001561,0.001584,0.001559,0.001575,0.001581,0.001555,0.001584,0.001577,0.001576,0.001557,0.00159,0.001557,0.001563,0.001548,0.001628,0.00157,0.001584,0.001559,0.001551,0.001556,0.001557,0.001567,0.001555,0.001562,0.001551,0.001575,0.001585,0.00157,0.001558,0.001608,0.001553,0.001548,0.001621,0.001561,0.001604,0.001589,0.00157,0.001547,0.001567,0.001552,0.001561,0.001548,0.001549,0.001557,0.001556,0.001561,0.001551,0.001563,0.001551,0.001591,0.001776,0.001572,0.001555,0.001554,0.001568,0.001553,0.00157,0.001555,0.001609,0.001554,0.001569,0.001549,0.001604,0.001573,0.001621,0.00155,0.001555,0.001569,0.001554,0.001598,0.001554,0.001564,0.001547,0.001582,0.001558,0.001568,0.00155,0.001549,0.001572,0.001555,0.001585,0.001587,0.001576,0.001547,0.001566,0.001563,0.001602,0.001552,0.001556,0.001567,0.001554,0.001587,0.001555,0.001572,0.001556,0.001573,0.001555,0.001571,0.001554,0.001634,0.001552,0.001556,0.001564,0.001565,0.001584,0.001564,0.001599,0.001555,0.001564,0.001555,0.001585,0.001558,0.001561,0.001564,0.001549,0.001603,0.001556,0.001602,0.002294,0.002287,0.001617,0.001572,0.001585,0.001564,0.001548,0.001677,0.001549,0.001588,0.001569,0.001594,0.001559,0.001579,0.001548,0.001566,0.001573,0.001578,0.001616,0.001556,0.001647,0.001554,0.001648,0.00155,0.001579,0.001594,0.001661,0.001577,0.001577,0.00158,0.001565,0.001555,0.001553,0.001569,0.001557,0.001589,0.001556,0.001594,0.001557,0.001571,0.001562,0.00157,0.001556,0.001609,0.001556,0.001556,0.001583,0.001553,0.001594,0.001546,0.001573,0.001554,0.001774,0.001557,0.001566,0.001561,0.001561,0.001556,0.00156,0.001594,0.001569,0.001841,0.00155,0.001571,0.00157,0.001573,0.001555,0.001589,0.001568,0.00161,0.001572,0.001573,0.001588,0.001547,0.001583,0.001565,0.001585,0.001571,0.00158,0.001613,0.001567,0.001587,0.001556,0.001556,0.001571,0.001574,0.00156,0.001563,0.001557,0.001573,0.001563,0.001574,0.001568,0.001568,0.001556,0.001553,0.001572,0.00155,0.001594,0.001583,0.00159,0.001555,0.001593,0.001579,0.001664,0.001568,0.001565,0.001581,0.001557,0.001593,0.001632,0.001619,0.001558,0.00171,0.001554,0.001584,0.001559,0.001593,0.001561,0.001589,0.00156,0.001554,0.001563,0.001556,0.001584,0.001556,0.001575,0.001552,0.001569,0.001556,0.001572,0.001596,0.001551,0.001556,0.001597,0.001597,0.001559,0.001577,0.001551,0.001568,0.001559,0.00157,0.001555,0.001569,0.00155,0.001553,0.001587,0.001563,0.001616,0.001554,0.001571,0.001552,0.001602,0.001562,0.001578,0.001548,0.001593,0.001568,0.001559,0.001577,0.001559,0.001608,0.001553,0.001565,0.001592,0.001598,0.001564,0.001576,0.001568,0.001561,0.001562,0.001561,0.001633,0.001556,0.001568,0.00155,0.001562,0.001562,0.00157,0.00158,0.001549,0.001555,0.001561,0.00162,0.001801,0.00158,0.001558,0.001563,0.001549,0.001569,0.001559,0.001571,0.001556,0.00155,0.001557,0.001556,0.001573,0.001559,0.001568,0.001552,0.001582,0.001565,0.001579,0.001561,0.001587,0.001553,0.001552,0.001561,0.001556,0.001591,0.00155,0.001571,0.001559,0.001614,0.001565,0.001584,0.001588,0.001554,0.001565,0.001554,0.001602,0.001568,0.001613,0.001564,0.001567,0.001554,0.001621,0.001579,0.001581,0.001562,0.001555,0.001558,0.001554,0.001595,0.001592,0.001581,0.001553,0.00157,0.001555,0.001576,0.001614,0.001578,0.001556,0.001599,0.001574,0.001565,0.001574,0.001563,0.001568,0.001562,0.001566,0.001564,0.001631,0.00156,0.001583,0.001568,0.001557,0.001576,0.001561,0.001576,0.001557,0.001613,0.001559,0.001581,0.001559,0.001578,0.001581,0.001555,0.001561,0.001562,0.001615,0.001563,0.001576,0.001556,0.001568,0.00156,0.001575,0.001574,0.001574,0.001553,0.001555,0.001561,0.001559,0.001574,0.001555,0.00157,0.001555,0.00162,0.001577,0.001607,0.001563,0.001554,0.001557,0.001563,0.001579,0.00156,0.00158,0.001556,0.001615,0.00156,0.001578,0.001559,0.001579,0.001557,0.001556,0.001557,0.001563,0.001588,0.001561,0.001607,0.001579,0.001579,0.001564,0.001577,0.001562,0.001579,0.001553,0.001554,0.001598,0.001558,0.001592,0.001565,0.001672,0.001612,0.001604,0.001612,0.001618,0.001566,0.001597,0.001557,0.001555,0.001575,0.001556,0.001577,0.001563,0.001579,0.001561,0.00157,0.001564,0.001578,0.001565,0.001604,0.001571,0.001554,0.001552,0.001568,0.001579,0.001594,0.001566,0.001603,0.001571,0.001563,0.001629,0.001578,0.001577,0.001585,0.001555,0.001611,0.001562,0.001582,0.001566,0.001605,0.001557,0.001572,0.001563,0.001583,0.001563,0.00157,0.001556,0.001554,0.001574,0.001556,0.00157,0.001556,0.001573,0.001557,0.001573,0.001558,0.001577,0.001557,0.001557,0.001561,0.001574,0.00157,0.00156,0.001588,0.001557,0.001577,0.001561,0.00157,0.001578,0.001713,0.001858,0.001699,0.001571,0.00157,0.001588,0.001579,0.00158,0.001561,0.001569,0.001554,0.001568,0.001572,0.00159,0.001561,0.00159,0.001573,0.001558,0.001562,0.001564,0.001581,0.001578,0.001572,0.00156,0.001581,0.001566,0.001579,0.001581,0.001616,0.001562,0.001558,0.001568,0.00156,0.00161,0.001572,0.001569,0.001571,0.001648,0.001567,0.001592,0.00156,0.001596,0.001563,0.001585,0.001568,0.001565,0.001601,0.00156,0.001593,0.001555,0.001586,0.001565,0.0016,0.001567,0.001597,0.001557,0.001573,0.001695,0.001579,0.001675,0.001566,0.001593,0.001571,0.001672,0.001745,0.001736,0.001762,0.001604,0.00157,0.001647,0.001575,0.001614,0.001957,0.001569,0.001567,0.00158,0.001564,0.001644,0.00171,0.0016,0.001572,0.001558,0.001572,0.001564,0.001577,0.00157,0.001573,0.001568,0.001587,0.001565,0.001579,0.001577,0.001555,0.001557,0.001564,0.00167,0.001656,0.001639,0.001561,0.001575,0.001555,0.001596,0.001562,0.001578,0.001618,0.001657,0.001622,0.001608,0.001594,0.00168,0.001572,0.001595,0.001605,0.001572,0.001641,0.001571,0.001587,0.001606,0.001584,0.001564,0.00158,0.001567,0.001602,0.001616,0.001561,0.001564,0.001568,0.001609,0.001565,0.001586,0.001818,0.001586,0.00156,0.001588,0.00175,0.001621,0.001565,0.001585,0.001578,0.001588,0.001588,0.001569,0.001578,0.001655,0.001671,0.001563,0.00159,0.001572,0.001717,0.001659,0.001604,0.001595,0.001623,0.001567,0.001602,0.00171,0.001782,0.001639,0.001863,0.001633,0.001676,0.001634,0.001637,0.001751,0.001686,0.001592,0.001639,0.00158,0.001596,0.001588,0.001565,0.00159,0.001599,0.00159,0.001562,0.001603,0.001562,0.001575,0.001565,0.001593,0.001566,0.001578,0.001567,0.001555,0.00158,0.001566,0.001622,0.001555,0.001578,0.001559,0.001584,0.001566,0.001604,0.001564,0.001779,0.001569,0.001562,0.001586,0.001561,0.001591,0.001575,0.001583,0.001558,0.001582,0.001564,0.001583,0.001571,0.001594,0.001587,0.00157,0.001573,0.001578,0.001593,0.001565,0.001644,0.001571,0.001592,0.001556,0.001629,0.001567,0.001586,0.001566,0.001599,0.001561,0.001559,0.001587,0.001574,0.001601,0.001556,0.001599,0.001598,0.001631,0.001568,0.00158,0.001569,0.001584,0.001573,0.001559,0.001589,0.001569,0.001594,0.001562,0.001583,0.001559,0.001582,0.001567,0.001588,0.001569,0.001562,0.001972,0.00162,0.001577,0.001573,0.001573,0.001572,0.001617,0.001571,0.001633,0.001564,0.001602,0.001569,0.001588,0.001581,0.001586,0.001563,0.001564,0.001566,0.001774,0.001573,0.001572,0.001588,0.001579,0.001625,0.001562,0.001576,0.001578,0.001594,0.001576,0.001582,0.001562,0.001608,0.001561,0.001569,0.001599,0.001585,0.001581,0.001569,0.001579,0.001567,0.001592,0.001568,0.001585,0.001567,0.001593,0.001576,0.001574,0.001592,0.00157,0.001586,0.001569,0.001631,0.001564,0.001588,0.001567,0.001612,0.001591,0.001585,0.001564,0.001593,0.001573,0.001605,0.001618,0.001608,0.001574,0.001579,0.001586,0.001569,0.001628,0.001575,0.001599,0.001611,0.001589,0.001748,0.001646,0.00157,0.001569,0.001585,0.001647,0.001793,0.001683,0.001666,0.00162,0.00165,0.001616,0.001664,0.001627,0.001614,0.001607,0.001578,0.001564,0.001579,0.001569,0.001611,0.001572,0.00159,0.001565,0.001564,0.001583,0.001575,0.001583,0.001568,0.001611,0.001562,0.001579,0.001575,0.001588,0.001963,0.001627,0.001584,0.001603,0.001561,0.001959,0.001598,0.001618,0.001581,0.001559,0.001618,0.001568,0.001665,0.001567,0.001598,0.001563,0.001597,0.001572,0.001602,0.001567,0.001599,0.001568,0.001567,0.001578,0.001574,0.001583,0.001566,0.00158,0.00157,0.001574,0.00157,0.001645,0.001563,0.001576,0.001576,0.001591,0.001569,0.001673,0.001582,0.001569,0.001608,0.001565,0.001578,0.001571,0.001581,0.00159,0.001599,0.001608,0.001562,0.001566,0.001586,0.001585,0.00157,0.001583,0.001561,0.00158,0.001574,0.001597,0.00157,0.001601,0.001577,0.001564,0.001606,0.001721,0.001714,0.001579,0.001626,0.001571,0.002313,0.001577,0.001567,0.001571,0.001597,0.0016,0.001618,0.001561,0.0016,0.001564,0.00162,0.00157,0.001603,0.001617,0.001561,0.001564,0.001564,0.001601,0.001649,0.001625,0.001597,0.001577,0.001564,0.001583,0.001575,0.001615,0.00157,0.001812,0.00172,0.001645,0.001771,0.001672,0.001563,0.001583,0.001563,0.001693,0.001592,0.00157,0.001948,0.001585,0.001587,0.001563,0.001604,0.001776,0.001624,0.001566,0.001632,0.001573,0.001969,0.001584,0.001625,0.00157,0.001595,0.001561,0.0016,0.001659,0.001652,0.002324,0.001641,0.001576,0.001758,0.001922,0.001639,0.001574,0.001614,0.001568,0.001704,0.001729,0.00176,0.001675,0.001584,0.001585,0.001617,0.001581,0.001599,0.001675,0.001619,0.001568,0.00161,0.001691,0.001603,0.001616,0.001768,0.001628,0.001571,0.001602,0.001572,0.001666,0.001727,0.00165,0.001646,0.001593,0.001583,0.001589,0.001571,0.001586,0.001572,0.001566,0.00162,0.00158,0.001589,0.001574,0.001908,0.001575,0.001597,0.001985,0.001622,0.00159,0.001622,0.002349,0.001614,0.001613,0.00188,0.00231,0.002308,0.0021,0.001576,0.001716,0.003655,0.002871,0.00277,0.002566,0.002591,0.002687,0.002627,0.00273,0.002608,0.002607,0.002529,0.002564,0.002621,0.00255,0.002494,0.002598,0.002528,0.00262,0.002642,0.002529,0.002818,0.002073,0.002404,0.002148,0.0016,0.001606,0.001627,0.001645,0.001588,0.001594,0.001642,0.001632,0.001628,0.002185,0.001696,0.00158,0.001578,0.001793,0.001671,0.001594,0.001615,0.001574,0.001788,0.001576,0.001608,0.001588,0.001606,0.001569,0.001605,0.001628,0.002013,0.001722,0.00163,0.001592,0.001592,0.001574,0.001596,0.001574,0.001565,0.001768,0.00158,0.001624,0.001585,0.001626,0.001751,0.001609,0.001578,0.001588,0.001701,0.001727,0.001578,0.001623,0.001599,0.001622,0.001588,0.001593,0.001566,0.001565,0.001599,0.001571,0.001787,0.001981,0.001577,0.001578,0.001633,0.001996,0.001605,0.001573,0.001644,0.001885,0.002323,0.002325,0.001978,0.001653,0.001608,0.002375,0.002462,0.002311,0.00232,0.002449,0.002453,0.002394,0.002435,0.00245,0.001631,0.001587,0.001647,0.001581,0.001621,0.00189,0.001641,0.001617,0.001604,0.001569,0.001614,0.001629,0.001619,0.001607,0.001656,0.00166,0.001621,0.001591,0.001825,0.00189,0.001996,0.002431,0.001583,0.001584,0.00159,0.001649,0.001677,0.001586,0.00161,0.001574,0.001667,0.001644,0.001645,0.001666,0.001653,0.001622,0.001626,0.001641,0.001691,0.001579,0.001704,0.002479,0.002939,0.002852,0.001713,0.002434,0.002644,0.00257,0.002668,0.002631,0.002473,0.002492,0.00251,0.002392,0.00257,0.002436,0.002537,0.00245,0.002448,0.00252,0.002426,0.002444,0.00252,0.002304,0.002478,0.002346,0.00251,0.002563,0.00257,0.00257,0.002502,0.001582,0.002316,0.002456,0.00172,0.001715,0.00228,0.002515,0.002275,0.002438,0.002773,0.002532,0.002664,0.002516,0.002591,0.00249,0.002465,0.002486,0.002504,0.002485,0.002469,0.002483,0.002541,0.0025,0.002568,0.002549,0.002499,0.002472,0.002378,0.002679,0.002683,0.002464,0.002556,0.002496,0.002485,0.002488,0.002544,0.002489,0.002487,0.002548,0.002467,0.002507,0.002529,0.002544,0.002513,0.002722,0.002025,0.00245,0.001661,0.001614,0.001994,0.002456,0.002575,0.001701,0.001653,0.001778,0.001683,0.001873,0.001591,0.00179,0.001612,0.00167,0.001919,0.002625,0.002626,0.002583,0.002542,0.002663,0.00213,0.001645,0.001765,0.001638,0.001682,0.00166,0.001727,0.002049,0.002592,0.002571,0.00254,0.002541,0.002474,0.002477,0.002449,0.002471,0.002498,0.002465,0.002394,0.002592,0.002597,0.002706,0.002611,0.002497,0.0025,0.002404,0.0024,0.002412,0.002671,0.002507,0.002495,0.002573,0.002492,0.002109,0.001635,0.001997,0.00158,0.001606,0.001729,0.002541,0.002519,0.002525,0.001633,0.001579,0.001614,0.001577,0.001636,0.001574,0.001611,0.001575,0.00238,0.002525,0.001679,0.001589,0.001904,0.002536,0.002537,0.002504,0.002552,0.002552,0.002534,0.00253,0.002552,0.002508,0.002502,0.002504,0.00246,0.00159,0.001664,0.001604,0.001766,0.001966,0.00275,0.002614,0.002479,0.002542,0.002542,0.002559,0.002522,0.002143,0.001587,0.002131,0.002271,0.002599,0.001851,0.001656,0.00239,0.001851,0.001654,0.002073,0.001621,0.002124,0.001633,0.001894,0.002631,0.001608,0.001638,0.001637,0.001638,0.00164,0.001578,0.001687,0.001577,0.001637,0.001599,0.001679,0.001644,0.001648,0.0016,0.001647,0.00164,0.001761,0.001636,0.001635,0.001573,0.001663,0.001784,0.002472,0.001985,0.002186,0.002069,0.001688,0.001685,0.001648,0.001838,0.001648,0.001692,0.001663,0.001752,0.001657,0.001624,0.001648,0.001659,0.001654,0.001606,0.001616,0.001664,0.001608,0.001569,0.001597,0.001646,0.001757,0.001703,0.002365,0.002543,0.00189,0.001856,0.001623,0.001622,0.001586,0.001596,0.001585,0.001595,0.001575,0.001591,0.001576,0.001591,0.001588,0.001582,0.001602,0.001578,0.001638,0.001575,0.001602,0.00158,0.0016,0.001597,0.001582,0.002019,0.001894,0.002434,0.002571,0.002124,0.002151,0.001607,0.00198,0.001881,0.001577,0.001628,0.002012,0.001705,0.002355,0.001702,0.001782,0.002507,0.002516,0.001659,0.002508,0.001885,0.001654,0.001686,0.001667,0.001614,0.00158,0.001601,0.001581,0.001662,0.001574,0.001597,0.001591,0.001569,0.00157,0.001576,0.001602,0.00158,0.001637,0.001575,0.001596,0.001578,0.001595,0.001592,0.001595,0.001642,0.001646,0.00171,0.002529,0.002483,0.00257,0.002547,0.002644,0.002488,0.002578,0.002547,0.0025,0.002508,0.002586,0.002617,0.002503,0.002506,0.00253,0.002496,0.002447,0.002476,0.002538,0.002498,0.002561,0.001958,0.001581,0.001636,0.001578,0.001583,0.001618,0.001629,0.001591,0.001576,0.001608,0.001593,0.001624,0.001596,0.0016,0.001578,0.001606,0.001617,0.001599,0.00161,0.001603,0.001597,0.00182,0.002502,0.002553,0.002491,0.002498,0.002573,0.002525,0.002476,0.002564,0.002545,0.002592,0.00246,0.001764,0.001576,0.001615,0.001583,0.0016,0.001773,0.001916,0.001616,0.001692,0.001581,0.001602,0.001581,0.001591,0.001674,0.001928,0.002012,0.001601,0.001774,0.00202,0.001598,0.001618,0.001581,0.001598,0.001587,0.001594,0.001578,0.001602,0.00158,0.001582,0.001614,0.00168,0.00164,0.001758,0.001599,0.002117,0.00193,0.001636,0.002388,0.002538,0.002522,0.002562,0.00271,0.002666,0.00237,0.001644,0.002009,0.002307,0.001758,0.002057,0.001756,0.00166,0.002537,0.002192,0.001618,0.001614,0.001607,0.001685,0.001691,0.001615,0.00159,0.001634,0.001683,0.001575,0.001653,0.00183,0.001587,0.001579,0.001592,0.001581,0.001587,0.001598,0.001587,0.001575,0.001584,0.001581,0.001594,0.001602,0.001604,0.001581,0.001574,0.001668,0.002465,0.002474,0.002494,0.0025,0.002465,0.001735,0.00158,0.001631,0.00167,0.002474,0.00252,0.002438,0.002488,0.002461,0.002447,0.002449,0.002382,0.002434,0.001581,0.001575,0.001592,0.001572,0.001614,0.001582,0.001617,0.001585,0.001605,0.001575,0.001603,0.001607,0.001622,0.0016,0.001592,0.001573,0.001572,0.001574,0.001578,0.001593,0.001579,0.001586,0.001572,0.001589,0.001573,0.001593,0.001579,0.001591,0.001659,0.002507,0.002478,0.002467,0.002502,0.00242,0.002356,0.00175,0.001593,0.001608,0.001601,0.001612,0.001589,0.001576,0.001592,0.001575,0.002495,0.002465,0.002528,0.002442,0.001934,0.001583,0.001617,0.001575,0.001618,0.001583,0.001617,0.001597,0.001595,0.001574,0.001581,0.001576,0.001584,0.001614,0.001582,0.00164,0.001578,0.001598,0.001576,0.001603,0.001591,0.001597,0.001579,0.001579,0.001593,0.001578,0.00161,0.001587,0.001621,0.002218,0.0025,0.002523,0.002547,0.002497,0.002517,0.002578,0.002555,0.002517,0.00246,0.002571,0.002505,0.002531,0.001921,0.001588,0.001696,0.001583,0.001578,0.001576,0.00158,0.001636,0.00158,0.001597,0.001579,0.001589,0.00158,0.001583,0.00158,0.001592,0.00158,0.001595,0.001585,0.001575,0.001594,0.001583,0.001594,0.001636,0.001602,0.001574,0.001585,0.001588,0.001595,0.001595,0.001605,0.001573,0.001578,0.001577,0.001602,0.001598,0.002446,0.002553,0.002591,0.002531,0.002452,0.002497,0.002497,0.002523,0.002465,0.002545,0.00254,0.002486,0.001698,0.001582,0.001624,0.001665,0.001617,0.001579,0.001612,0.00158,0.001631,0.001595,0.001607,0.001746,0.00179,0.001755,0.001668,0.001584,0.001849,0.001651,0.001646,0.001578,0.001586,0.00159,0.001631,0.001637,0.001588,0.001663,0.001635,0.001663,0.001588,0.00159,0.00158,0.001598,0.001933,0.002577,0.0027,0.002662,0.002633,0.002641,0.002236,0.002026,0.001696,0.001618,0.002477,0.002585,0.00227,0.001771,0.002344,0.002811,0.002422,0.001689,0.00167,0.001588,0.001657,0.001628,0.00175,0.001703,0.001663,0.001643,0.001765,0.00164,0.001656,0.001616,0.001652,0.001608,0.001655,0.001587,0.001655,0.00167,0.00166,0.001644,0.001612,0.001581,0.001595,0.001658,0.001602,0.001599,0.001583,0.001603,0.002218,0.002176,0.001781,0.001985,0.002126,0.002243,0.002072,0.002399,0.002056,0.001686,0.001578,0.001613,0.001588,0.001701,0.001604,0.001725,0.001633,0.001696,0.001591,0.001577,0.001598,0.001637,0.001599,0.001827,0.00263,0.002178,0.001653,0.001678,0.001646,0.001652,0.001741,0.001626,0.001589,0.001644,0.001655,0.001634,0.001964,0.002405,0.002413,0.002311,0.002395,0.002588,0.002495,0.002598,0.002478,0.00203,0.001884,0.001866,0.001651,0.001652,0.001701,0.001698,0.001692,0.001702,0.001836,0.002325,0.001649,0.001693,0.002846,0.001711,0.001841,0.001902,0.002631,0.002625,0.002386,0.002496,0.002516,0.002536,0.002557,0.001741,0.002363,0.002589,0.002587,0.001983,0.001659,0.001605,0.001959,0.001636,0.001675,0.001626,0.00169,0.002026,0.002204,0.002122,0.001615,0.001693,0.001602,0.001643,0.001667,0.00158,0.001637,0.002095,0.001684,0.001857,0.001782,0.001698,0.00165,0.001692,0.001654,0.002187,0.002636,0.001679,0.001995,0.0026,0.001964,0.001711,0.001693,0.001654,0.001657,0.001665,0.001825,0.001601,0.001646,0.001609,0.001717,0.001892,0.002315,0.002446,0.001596,0.002428,0.002532,0.002547,0.002524,0.00252,0.002495,0.002521,0.002546,0.002514,0.00246,0.002568,0.002556,0.002541,0.00256,0.002527,0.00217,0.001632,0.001624,0.002313,0.00234,0.001626,0.001636,0.001603,0.001632,0.001581,0.001707,0.001656,0.001586,0.001631,0.00159,0.001641,0.002515,0.002811,0.00258,0.002588,0.002565,0.002537,0.002505,0.002495,0.002511,0.002524,0.002558,0.002494,0.002397,0.002609,0.002554,0.002551,0.002771,0.002084,0.00303,0.002086,0.00164,0.002092,0.002938,0.002317,0.001864,0.001813,0.00164,0.002014,0.001906,0.002333,0.001707,0.001644,0.001711,0.001656,0.002397,0.002506,0.001725,0.001747,0.002464,0.002758,0.002675,0.00265,0.002542,0.002601,0.002654,0.00261,0.002535,0.002483,0.002615,0.002531,0.00242,0.00182,0.00199,0.002477,0.00251,0.002613,0.002635,0.002836,0.002546,0.002542,0.002513,0.002525,0.002456,0.002507,0.002544,0.002491,0.00252,0.002463,0.002564,0.00191,0.001727,0.00158,0.001616,0.001581,0.001875,0.002558,0.002527,0.002559,0.00256,0.00257,0.002592,0.002753,0.002534,0.002555,0.002544,0.00256,0.00249,0.002533,0.002596,0.002516,0.002586,0.002532,0.002671,0.002628,0.002576,0.002555,0.00255,0.001936,0.002282,0.001611,0.001667,0.00184,0.002554,0.002557,0.00253,0.002441,0.002549,0.002491,0.00254,0.002513,0.002527,0.002485,0.002492,0.00257,0.002581,0.002673,0.002675,0.002058,0.002284,0.002825,0.002528,0.002577,0.002522,0.002643,0.002656,0.002508,0.002492,0.002515,0.002527,0.002543,0.002466,0.002569,0.002513,0.002547,0.002597,0.002533,0.002234,0.002383,0.002045,0.001588,0.001644,0.002493,0.002562,0.002558,0.002517,0.002686,0.002734,0.00252,0.002525,0.002544,0.002343,0.001598,0.001685,0.001602,0.001631,0.001608,0.001817,0.002234,0.001618,0.001867,0.002425,0.001965,0.001622,0.00162,0.001624,0.00159,0.001634,0.001857,0.001651,0.001589,0.001653,0.001592,0.001723,0.002172,0.001632,0.001678,0.002288,0.002401,0.001628,0.001668,0.00163,0.00162,0.001589,0.00164,0.001785,0.001637,0.001583,0.001618,0.001611,0.002442,0.001839,0.001634,0.002053,0.002629,0.001964,0.001613,0.001622,0.001623,0.001611,0.001638,0.001909,0.001613,0.001595,0.001615,0.001598,0.002455,0.002056,0.001734,0.002449,0.002375,0.001644,0.001635,0.001685,0.001617,0.001638,0.001943,0.001664,0.001656,0.001686,0.001627,0.002366,0.002549,0.001619,0.001763,0.001619,0.002337,0.002585,0.002394,0.00251,0.002292,0.001948,0.002382,0.001815,0.001612,0.00191,0.001606,0.001602,0.001593,0.001621,0.001852,0.002689,0.002721,0.00249,0.002577,0.002552,0.002497,0.002817,0.002706,0.002783,0.002631,0.002641,0.002503,0.002603,0.002516,0.002671,0.002587,0.002197,0.002444,0.001721,0.001584,0.002314,0.002368,0.001627,0.001614,0.001634,0.001598,0.00164,0.001613,0.001939,0.001617,0.001615,0.001595,0.001647,0.002462,0.001982,0.001799,0.002084,0.002507,0.002034,0.001689,0.001693,0.001736,0.00166,0.00163,0.001895,0.001721,0.001651,0.001616,0.001678,0.002,0.002369,0.001622,0.001695,0.00242,0.002481,0.001701,0.001679,0.001608,0.001593,0.001592,0.001658,0.001749,0.001623,0.001584,0.001699,0.00166,0.002505,0.002476,0.002666,0.002544,0.001847,0.001691,0.001722,0.001637,0.001649,0.001601,0.001629,0.001586,0.00169,0.0016,0.00183,0.00254,0.002571,0.002562,0.00256,0.002409,0.002349,0.00159,0.001632,0.002112,0.002405,0.001764,0.001597,0.001938,0.001601,0.001662,0.00163,0.001966,0.001607,0.001636,0.001609,0.001623,0.002066,0.002143,0.00165,0.001739,0.002363,0.002175,0.001711,0.001743,0.001614,0.001588,0.001612,0.001887,0.001624,0.001664,0.001613,0.001658,0.001977,0.00241,0.001621,0.001602,0.002584,0.002387,0.001681,0.001711,0.001671,0.00159,0.001637,0.001866,0.001802,0.001702,0.00165,0.001589,0.001671,0.002637,0.001681,0.00169,0.002389,0.002346,0.001687,0.001617,0.001728,0.001644,0.001611,0.00166,0.001716,0.001662,0.001645,0.001593,0.00172,0.002527,0.001937,0.001631,0.002077,0.002399,0.001862,0.001604,0.001586,0.001619,0.001626,0.001617,0.001946,0.001634,0.001682,0.001594,0.001717,0.002268,0.002273,0.002332,0.001652,0.001637,0.001648,0.001691,0.001589,0.001648,0.001609,0.001649,0.001608,0.001644,0.00162,0.001639,0.001589,0.001597,0.001592,0.001598,0.001653,0.001598,0.001606,0.001601,0.001605,0.001595,0.001631,0.001587,0.001634,0.001603,0.00163,0.001611,0.001587,0.001587,0.001589,0.001593,0.001595,0.001706,0.001621,0.001621,0.001601,0.00179,0.001821,0.001655,0.00159,0.001636,0.001611,0.001631,0.001599,0.00164,0.001613,0.001623,0.001638,0.001604,0.001599,0.001604,0.001587,0.001584,0.001612,0.001598,0.001605,0.00159,0.001614,0.001587,0.001609,0.001594,0.001614,0.0016,0.001763,0.001595,0.001605,0.001587,0.001631,0.001612,0.001592,0.001664,0.002191,0.001668,0.001598,0.00162,0.001615,0.001621,0.001608,0.001626,0.001605,0.001618,0.001598,0.001611,0.001607,0.001673,0.001599,0.001621,0.001612,0.001656,0.001697,0.001636,0.001598,0.001608,0.001593,0.001598,0.001626,0.001603,0.001639,0.001595,0.001643,0.001598,0.001607,0.001627,0.001604,0.001672,0.00162,0.001598,0.001631,0.001595,0.001601,0.001608,0.001594,0.001624,0.001596,0.001614,0.001598,0.001616,0.001608,0.00162,0.001984,0.001662,0.001596,0.001604,0.001605,0.001762,0.002187,0.002495,0.002288,0.002295,0.00167,0.001593,0.001645,0.00159,0.001651,0.001598,0.001636,0.001694,0.001632,0.001602,0.001672,0.00186,0.001668,0.001623,0.001644,0.001625,0.001589,0.001597,0.001602,0.001611,0.001601,0.001783,0.001591,0.00162,0.001597,0.001624,0.001591,0.001687,0.001597,0.001626,0.001644,0.00172,0.00176,0.001706,0.001625,0.001675,0.001598,0.001675,0.001615,0.001619,0.001659,0.001708,0.001664,0.001629,0.001595,0.001634,0.001615,0.001654,0.001752,0.001599,0.001626,0.001598,0.001632,0.001594,0.00166,0.00165,0.001643,0.001598,0.001603,0.001605,0.001622,0.001598,0.001612,0.001605,0.00159,0.001593,0.001597,0.001613,0.001641,0.001618,0.001598,0.001601,0.001591,0.001609,0.001596,0.00161,0.001608,0.001608,0.001654,0.001617,0.001596,0.001593,0.001592,0.001797,0.00161,0.001598,0.00162,0.001595,0.001612,0.001597,0.001603,0.001589,0.00161,0.001598,0.00162,0.001611,0.001609,0.00159,0.001592,0.001592,0.001598,0.001625,0.001595,0.001608,0.001594,0.001625,0.001595,0.001605,0.001608,0.001619,0.001599,0.001608,0.00164,0.001606,0.001589,0.001595,0.001981,0.001608,0.001588,0.001598,0.001634,0.00162,0.001629,0.001595,0.001625,0.001592,0.001635,0.001591,0.001611,0.0016,0.00161,0.001598,0.001603,0.001591,0.001595,0.001596,0.001597,0.001636,0.001599,0.001615,0.001592,0.001622,0.001617,0.001637,0.0016,0.001623,0.001745,0.001756,0.001718,0.001737,0.001688,0.001627,0.001627,0.001672,0.001626,0.001652,0.001596,0.001742,0.001683,0.001676,0.001607,0.00164,0.001627,0.001621,0.001617,0.001608,0.001595,0.001604,0.001632,0.001626,0.001621,0.001608,0.001628,0.001637,0.00171,0.001626,0.00165,0.001597,0.001715,0.001617,0.001617,0.001612,0.001637,0.001605,0.001619,0.001616,0.001814,0.001609,0.001633,0.001696,0.001605,0.001608,0.001599,0.001639,0.001701,0.001686,0.001625,0.00162,0.001599,0.001636,0.001597,0.001607,0.001597,0.001622,0.001612,0.001623,0.001712,0.001667,0.001594,0.00162,0.001657,0.00168,0.001736,0.001697,0.001654,0.001625,0.001625,0.001596,0.00167,0.001736,0.001856,0.001774,0.001607,0.001606,0.001763,0.001611,0.001662,0.001622,0.001647,0.001749,0.001646,0.001609,0.001623,0.001591,0.001622,0.001601,0.00161,0.001601,0.001624,0.001601,0.001618,0.001611,0.001592,0.001599,0.001591,0.001626,0.00161,0.001616,0.001616,0.00161,0.001634,0.001641,0.001591,0.001619,0.001607,0.001623,0.001671,0.001663,0.0016,0.001683,0.001603,0.001597,0.001614,0.001605,0.001629,0.001606,0.001616,0.001602,0.001613,0.0016,0.001613,0.001595,0.001619,0.001923,0.001621,0.001605,0.001621,0.001621,0.001619,0.001644,0.001688,0.001832,0.001712,0.001708,0.001676,0.001732,0.001662,0.001642,0.001645,0.001625,0.001593,0.001593,0.001596,0.001636,0.001605,0.001616,0.001603,0.001613,0.001595,0.001608,0.001595,0.001614,0.001602,0.001623,0.001621,0.001619,0.001596,0.001598,0.001597,0.001604,0.001614,0.001601,0.00161,0.001598,0.001622,0.001596,0.00161,0.001801,0.00165,0.001771,0.001689,0.001621,0.001625,0.001605,0.001844,0.001632,0.001814,0.001596,0.00164,0.00163,0.001661,0.001608,0.001641,0.001605,0.001597,0.001615,0.001594,0.001622,0.001604,0.001615,0.001623,0.00161,0.001609,0.001639,0.001595,0.001645,0.001621,0.001888,0.001606,0.001672,0.001602,0.001675,0.002063,0.001634,0.00161,0.001715,0.001832,0.001779,0.001739,0.001721,0.001628,0.00162,0.001599,0.001619,0.001604,0.00162,0.00162,0.00164,0.001604,0.001595,0.001636,0.001598,0.001606,0.001613,0.001617,0.001602,0.001656,0.001596,0.001612,0.001599,0.001616,0.001628,0.00164,0.001605,0.001626,0.00165,0.001619,0.001615,0.001596,0.001598,0.001612,0.001622,0.00161,0.001616,0.001606,0.001614,0.001598,0.001611,0.001604,0.001623,0.001602,0.001616,0.001601,0.001612,0.001594,0.001597,0.001604,0.001606,0.001626,0.001602,0.001614,0.001598,0.001607,0.001599,0.001925,0.001883,0.001615,0.0016,0.001623,0.001653,0.001635,0.001604,0.001624,0.001605,0.001613,0.001597,0.001604,0.001597,0.001605,0.001655,0.00184,0.001643,0.001603,0.001634,0.001613,0.001627,0.001598,0.001636,0.001598,0.00162,0.001605,0.001616,0.001607,0.001613,0.001598,0.001596,0.001598,0.001597,0.001622,0.001607,0.001631,0.0016,0.001693,0.001597,0.001615,0.001605,0.001613,0.001603,0.001623,0.001603,0.001645,0.001619,0.001595,0.001597,0.001597,0.001608,0.001606,0.001615,0.001601,0.001616,0.001602,0.001615,0.001598,0.001625,0.001606,0.00162,0.001603,0.001662,0.001596,0.0016,0.001603,0.0016,0.001634,0.001603,0.001619,0.001601,0.001662,0.001621,0.001611,0.0016,0.001624,0.001605,0.001618,0.00162,0.001613,0.001603,0.001601,0.001602,0.0016,0.00162,0.001604,0.001618,0.001611,0.001632,0.001602,0.001612,0.001599,0.001616,0.00161,0.001615,0.001607,0.001617,0.0016,0.001601,0.001613,0.001606,0.001622,0.001607,0.001617,0.001603,0.001611,0.001602,0.001617,0.00205,0.002124,0.001995,0.001693,0.001855,0.002486,0.001961,0.002324,0.001824,0.001599,0.001621,0.00181,0.001604,0.001601,0.001636,0.001612,0.001667,0.001607,0.001636,0.001604,0.001646,0.001601,0.001628,0.001614,0.001655,0.001608,0.001767,0.001605,0.001637,0.001799,0.001806,0.001628,0.001658,0.001602,0.001636,0.001865,0.001764,0.001631,0.001632,0.001602,0.00162,0.001619,0.001608,0.001639,0.001609,0.001624,0.001606,0.001617,0.001603,0.001611,0.001602,0.001619,0.00162,0.001615,0.001605,0.001627,0.001626,0.001599,0.001598,0.001602,0.001618,0.00168,0.001694,0.001605,0.001627,0.001722,0.001624,0.00201,0.001653,0.001607,0.001639,0.001598,0.00165,0.001907,0.00164,0.001598,0.001613,0.001608,0.001625,0.001613,0.001624,0.001604,0.001625,0.001618,0.001597,0.001602,0.001614,0.001623,0.001607,0.00162,0.001817,0.002322,0.001622,0.001619,0.001599,0.001645,0.001631,0.001655,0.001605,0.001658,0.001605,0.001643,0.001599,0.001637,0.001605,0.001626,0.001607,0.001654,0.001606,0.001624,0.001605,0.00168,0.001604,0.001602,0.001761,0.001901,0.001614,0.001601,0.001602,0.00161,0.001637,0.001859,0.001671,0.001611,0.001643,0.001606,0.001625,0.001601,0.001615,0.001622,0.001613,0.001612,0.001628,0.001606,0.001631,0.001624,0.001631,0.0016,0.001596,0.0016,0.001613,0.001631,0.001609,0.001623,0.001602,0.001654,0.001639,0.001618,0.001607,0.001623,0.00161,0.002131,0.002394,0.002362,0.002098,0.001614,0.001743,0.002723,0.002416,0.002553,0.002606,0.00254,0.002565,0.002594,0.002519,0.002556,0.002572,0.002571,0.00247,0.00258,0.002167,0.002501,0.00165,0.001981,0.002304,0.002531,0.002035,0.001646,0.001645,0.0016,0.0016,0.001649,0.001607,0.001646,0.001605,0.00164,0.001664,0.001885,0.001668,0.001724,0.001686,0.001786,0.001686,0.001701,0.001711,0.001668,0.001674,0.001703,0.001852,0.001693,0.001685,0.001622,0.001626,0.001722,0.001698,0.001654,0.0016,0.001635,0.001604,0.001715,0.00167,0.001673,0.001648,0.001655,0.001608,0.001631,0.001608,0.00166,0.001627,0.001612,0.001607,0.00161,0.001774,0.001686,0.00169,0.001624,0.001655,0.001612,0.001646,0.001599,0.001644,0.0016,0.001618,0.001613,0.001767,0.0017,0.001624,0.001608,0.00165,0.001643,0.001625,0.0016,0.001601,0.001612,0.001637,0.001627,0.001605,0.001654,0.001608,0.001637,0.001602,0.001636,0.001602,0.001621,0.00164,0.001783,0.00161,0.001648,0.001612,0.001647,0.001622,0.001602,0.001604,0.001605,0.00163,0.001792,0.001749,0.001612,0.001632,0.001609,0.001817,0.001616,0.001668,0.001622,0.001658,0.001611,0.001683,0.001618,0.001655,0.001625,0.001652,0.001613,0.001628,0.001613,0.001649,0.001733,0.001774,0.001615,0.001662,0.001612,0.001649,0.001615,0.001606,0.001609,0.0016,0.001631,0.001613,0.001737,0.001665,0.00165,0.001609,0.001651,0.001604,0.001645,0.001603,0.001744,0.001634,0.001684,0.001618,0.001648,0.001612,0.001629,0.001641,0.001635,0.001679,0.001696,0.001655,0.00164,0.001621,0.001605,0.001628,0.001616,0.001745,0.001712,0.001757,0.001621,0.00167,0.001702,0.001671,0.001668,0.001726,0.001647,0.002156,0.001946,0.001908,0.002518,0.002586,0.002503,0.002465,0.001714,0.001747,0.001725,0.002539,0.002128,0.001693,0.001729,0.001773,0.001645,0.001665,0.0017,0.001607,0.001689,0.00224,0.002072,0.001603,0.002353,0.002379,0.001811,0.002356,0.002056,0.002414,0.002417,0.002334,0.001642,0.002422,0.002405,0.001762,0.001638,0.001683,0.001616,0.001709,0.001657,0.002114,0.001633,0.001609,0.001614,0.00176,0.001827,0.001819,0.002403,0.00292,0.002527,0.002598,0.002579,0.002625,0.002552,0.002599,0.002616,0.002519,0.00262,0.002561,0.00265,0.002706,0.002718,0.002807,0.002743,0.002659,0.002997,0.002717,0.002774,0.003137,0.00252,0.002839,0.002943,0.003015,0.002978,0.002875,0.002911,0.002676,0.002369,0.001821,0.003157,0.002193,0.002502,0.002753,0.002601,0.002595,0.002656,0.002669,0.002648,0.007593,0.002755,0.002689,0.00257,0.002616,0.003917,0.002776,0.002734,0.002859,0.002436,0.002436,0.002479,0.00191,0.002078,0.00162,0.0017,0.001612,0.001739,0.001659,0.00172,0.00164,0.00178,0.001764,0.001652,0.001616,0.001679,0.001612,0.001678,0.001624,0.002481,0.001999,0.001606,0.001605,0.00161,0.00161,0.002343,0.00209,0.001798,0.001994,0.002045,0.001713,0.001867,0.002264,0.001671,0.001843,0.002437,0.002547,0.002496,0.00243,0.001883,0.00166,0.001623,0.001681,0.001613,0.001626,0.001611,0.001622,0.002256,0.002654,0.002536,0.002187,0.001829,0.003015,0.002255,0.002544,0.002117,0.001613,0.00228,0.001929,0.001691,0.001886,0.001769,0.002125,0.001864,0.00175,0.001755,0.001694,0.00203,0.002068,0.001634,0.001641,0.001615,0.001659,0.001631,0.001628,0.001606,0.001646,0.001617,0.001929,0.001637,0.001636,0.001617,0.001626,0.001616,0.001626,0.001614,0.001624,0.001606,0.001612,0.001672,0.00161,0.001636,0.001612,0.001626,0.002149,0.00161,0.00168,0.001634,0.001646,0.001897,0.001978,0.001922,0.001913,0.001756,0.002145,0.002169,0.002558,0.002055,0.001639,0.001862,0.001895,0.001787,0.00161,0.002057,0.001726,0.00165,0.002095,0.002135,0.002501,0.001667,0.001669,0.001757,0.001967,0.001608,0.001652,0.001616,0.001639,0.001631,0.00166,0.001617,0.001632,0.00161,0.001608,0.001616,0.001675,0.001621,0.001619,0.001675,0.002112,0.001761,0.001618,0.001628,0.001954,0.001608,0.001768,0.001889,0.002019,0.001633,0.001873,0.00178,0.001713,0.001996,0.001656,0.00242,0.002535,0.001717,0.002496,0.002579,0.002594,0.002593,0.002551,0.001946,0.001614,0.001737,0.001633,0.001643,0.001614,0.001668,0.001685,0.001673,0.001633,0.001723,0.00161,0.001662,0.001662,0.001761,0.00161,0.001652,0.001626,0.001669,0.001622,0.001665,0.001621,0.001613,0.001622,0.001611,0.001613,0.001618,0.001636,0.001675,0.001656,0.002149,0.002637,0.002759,0.002532,0.002632,0.002862,0.002812,0.002679,0.002614,0.002616,0.00243,0.002504,0.001747,0.001656,0.001983,0.001649,0.001651,0.001701,0.001688,0.002165,0.001826,0.001741,0.001692,0.00192,0.001826,0.00169,0.001752,0.001891,0.001756,0.001691,0.001801,0.001732,0.001712,0.001684,0.001699,0.001689,0.001684,0.001703,0.001897,0.001666,0.001666,0.001646,0.001744,0.002541,0.002603,0.001666,0.001639,0.001687,0.001612,0.001613,0.001614,0.001617,0.001772,0.001734,0.001641,0.002422,0.00261,0.002673,0.00269,0.002785,0.002794,0.002825,0.002534,0.001788,0.001646,0.001621,0.001662,0.001679,0.00168,0.001616,0.001661,0.001619,0.00165,0.001688,0.001697,0.001616,0.001636,0.001626,0.001626,0.001622,0.001649,0.001628,0.00164,0.001643,0.00169,0.001627,0.001626,0.001646,0.002541,0.002274,0.00191,0.001671,0.002176,0.002803,0.002477,0.001788,0.002299,0.002409,0.002606,0.001997,0.002204,0.002563,0.002627,0.002635,0.002692,0.002727,0.002027,0.001646,0.001754,0.001759,0.00186,0.001641,0.001661,0.001726,0.001653,0.001615,0.001655,0.001664,0.001649,0.00162,0.001655,0.001715,0.001855,0.001661,0.001638,0.001617,0.001632,0.001622,0.002054,0.001628,0.001735,0.002423,0.002722,0.002153,0.002237,0.002796,0.002804,0.002837,0.002725,0.002876,0.002814,0.002728,0.002647,0.002642,0.002199,0.001802,0.00172,0.001728,0.001641,0.001671,0.001662,0.001643,0.00183,0.00164,0.001619,0.001636,0.001653,0.001665,0.001612,0.001647,0.001629,0.001643,0.001612,0.001653,0.001624,0.00162,0.001619,0.001665,0.001638,0.001615,0.001649,0.001614,0.001642,0.001619,0.001644,0.001645,0.001664,0.001642,0.002326,0.00177,0.001737,0.001659,0.002512,0.002642,0.002685,0.002676,0.002629,0.002686,0.002527,0.002636,0.002604,0.00264,0.002683,0.002674,0.002619,0.002284,0.001622,0.001643,0.001614,0.001626,0.001637,0.001651,0.001619,0.001622,0.001634,0.001619,0.001631,0.001613,0.001626,0.001613,0.001631,0.001618,0.001639,0.001624,0.001643,0.001622,0.001665,0.001619,0.001652,0.001935,0.002589,0.002575,0.0026,0.002645,0.002674,0.002786,0.002899,0.002782,0.002697,0.002596,0.00261,0.001621,0.001643,0.001664,0.001648,0.001637,0.001616,0.001626,0.001613,0.001642,0.00161,0.001641,0.001621,0.001637,0.001619,0.001632,0.001617,0.001629,0.001612,0.001628,0.001632,0.001625,0.00162,0.001663,0.001623,0.001617,0.001631,0.001608,0.001636,0.001618,0.001661,0.00162,0.001634,0.001618,0.001659,0.002191,0.00251,0.002611,0.002563,0.002508,0.002602,0.002672,0.002708,0.002778,0.002629,0.002485,0.00271,0.002617,0.002584,0.002487,0.001624,0.001655,0.001617,0.001673,0.001636,0.001644,0.001617,0.001611,0.00162,0.001885,0.001616,0.001612,0.001634,0.001619,0.001653,0.001622,0.001635,0.00162,0.001631,0.001631,0.001626,0.001615,0.001627,0.001625,0.001639,0.001632,0.001666,0.001621,0.001634,0.001712,0.002523,0.002567,0.001639,0.001644,0.002586,0.002579,0.002663,0.002259,0.001929,0.001769,0.002471,0.002627,0.002652,0.002614,0.001826,0.001629,0.001646,0.001988,0.001659,0.001624,0.00166,0.00165,0.001667,0.001621,0.001641,0.001618,0.001651,0.001616,0.001638,0.001681,0.001676,0.001635,0.001642,0.001624,0.001659,0.001626,0.001612,0.001618,0.001617,0.001661,0.001621,0.001651,0.001619,0.001658,0.001622,0.001638,0.001958,0.001659,0.001672,0.002756,0.002901,0.002882,0.002879,0.002713,0.001949,0.001627,0.00166,0.001623,0.002569,0.002603,0.00229,0.00258,0.002635,0.002479,0.00256,0.002796,0.002544,0.00195,0.002553,0.002507,0.002224,0.001675,0.001628,0.001655,0.001626,0.001667,0.00166,0.00171,0.001621,0.001753,0.001692,0.002053,0.001623,0.001654,0.001619,0.001677,0.001943,0.001998,0.001678,0.002248,0.002479,0.001783,0.001782,0.001708,0.001746,0.001682,0.00174,0.002365,0.002628,0.002644,0.002662,0.002591,0.002078,0.00188,0.001622,0.002232,0.002389,0.001769,0.001658,0.001671,0.001647,0.001678,0.001683,0.001846,0.001669,0.001719,0.001675,0.001732,0.002276,0.002614,0.001976,0.001619,0.001672,0.001638,0.001715,0.00162,0.001647,0.001618,0.001667,0.001627,0.001859,0.001639,0.001669,0.001622,0.001694,0.002178,0.002714,0.00286,0.002556,0.002617,0.002605,0.002613,0.002552,0.002578,0.002579,0.002911,0.002733,0.002581,0.002642,0.002596,0.002593,0.002652,0.002125,0.002203,0.001629,0.002073,0.002387,0.00189,0.001638,0.001677,0.001628,0.001657,0.001671,0.001937,0.001621,0.001658,0.001623,0.001672,0.002391,0.001895,0.001617,0.002157,0.002476,0.001762,0.001671,0.001622,0.001645,0.001614,0.001669,0.001906,0.001646,0.001632,0.001649,0.001644,0.002545,0.002913,0.002567,0.002613,0.00263,0.002608,0.002526,0.002562,0.002634,0.002688,0.002565,0.002559,0.001846,0.001619,0.00176,0.001649,0.001658,0.001788,0.001843,0.002523,0.002915,0.002575,0.002611,0.002617,0.002617,0.002581,0.002614,0.002577,0.002581,0.002596,0.00252,0.002649,0.002622,0.002652,0.002627,0.002192,0.00162,0.002097,0.002798,0.002753,0.001628,0.001695,0.002129,0.002613,0.002603,0.002594,0.002602,0.002609,0.002585,0.002654,0.002607,0.002441,0.001885,0.001657,0.001636,0.001651,0.001619,0.001959,0.002697,0.002598,0.002714,0.002644,0.002539,0.002545,0.002482,0.002721,0.002812,0.002563,0.00262,0.002614,0.002561,0.002591,0.002575,0.002634,0.002572,0.002572,0.002533,0.002625,0.002591,0.002612,0.002603,0.002058,0.002328,0.002337,0.001965,0.001679,0.001627,0.0018,0.002551,0.002614,0.002625,0.002577,0.002543,0.002611,0.002556,0.00256,0.002549,0.002639,0.002627,0.002612,0.002643,0.002595,0.002154,0.001717,0.002862,0.002671,0.002577,0.002629,0.002604,0.002552,0.002573,0.002581,0.002588,0.002569,0.002597,0.002585,0.002631,0.002602,0.002619,0.002664,0.002216,0.001698,0.001626,0.002381,0.002306,0.001648,0.001673,0.001643,0.001661,0.001623,0.001815,0.001761,0.001707,0.001669,0.001729,0.001914,0.002579,0.001731,0.001895,0.002469,0.00209,0.001744,0.001645,0.002425,0.00235,0.001713,0.002186,0.002473,0.001924,0.001725,0.001807,0.002282,0.001696,0.001757,0.001674,0.001683,0.001675,0.001691,0.00162,0.001652,0.00163,0.001678,0.001876,0.001664,0.001687,0.00174,0.001659,0.001734,0.002323,0.001658,0.001636,0.002421,0.00224,0.001645,0.001676,0.001924,0.001663,0.001642,0.001786,0.001721,0.001667,0.001634,0.00162,0.001742,0.002602,0.001757,0.001671,0.00166,0.001649,0.00162,0.001679,0.001641,0.001651,0.001628,0.001676,0.001631,0.001937,0.001645,0.001658,0.001622,0.001652,0.001696,0.002735,0.002793,0.002559,0.002617,0.002692,0.002624,0.002539,0.002576,0.002564,0.002553,0.002612,0.002509,0.002656,0.002585,0.002624,0.002626,0.002158,0.002078,0.001665,0.002057,0.002406,0.001836,0.001671,0.00162,0.001667,0.001628,0.00168,0.001925,0.001679,0.001632,0.001649,0.001674,0.002627,0.00204,0.001625,0.001692,0.001655,0.00162,0.001623,0.001618,0.001664,0.001646,0.00184,0.001634,0.001661,0.00181,0.002444,0.001877,0.001754,0.001788,0.001703,0.001984,0.002486,0.001903,0.001698,0.001772,0.00182,0.001633,0.00171,0.001674,0.001657,0.001628,0.001661,0.001627,0.001702,0.001883,0.001662,0.00166,0.001685,0.001625,0.002106,0.002453,0.002523,0.001824,0.001668,0.001619,0.001829,0.001635,0.002011,0.002423,0.001847,0.001671,0.001631,0.001686,0.001658,0.001672,0.001937,0.001658,0.001633,0.001774,0.001704,0.001905,0.001986,0.001677,0.001999,0.002393,0.001898,0.001646,0.001844,0.001623,0.002016,0.002468,0.00258,0.002538,0.002604,0.002594,0.002626,0.002626,0.002641,0.00232,0.001655,0.001625,0.002407,0.002332,0.00165,0.001683,0.001642,0.001623,0.001634,0.001838,0.001639,0.001625,0.001625,0.001623,0.001965,0.002378,0.001653,0.001671,0.00239,0.002375,0.001653,0.001646,0.00164,0.00167,0.001636,0.001889,0.001638,0.001681,0.001635,0.001678,0.001715,0.00241,0.002768,0.002774,0.002571,0.00266,0.00274,0.002791,0.002618,0.002613,0.002682,0.002605,0.002588,0.002559,0.002751,0.002811,0.002736,0.002747,0.002273,0.001982,0.00167,0.001635,0.001672,0.001636,0.001675,0.001628,0.001657,0.001627,0.001655,0.001624,0.001653,0.001632,0.001662,0.001654,0.001668,0.001629,0.001661,0.001631,0.001625,0.001638,0.001622,0.001622,0.001631,0.001662,0.001628,0.001759,0.00163,0.001662,0.00163,0.001691,0.00163,0.001657,0.001638,0.001632,0.001625,0.001639,0.00163,0.001646,0.001637,0.001645,0.001643,0.001645,0.001629,0.001629,0.001707,0.001664,0.001636,0.001679,0.001637,0.001625,0.001672,0.001632,0.001649,0.001632,0.001646,0.001637,0.00164,0.001625,0.001652,0.001623,0.001645,0.001629,0.001653,0.001632,0.001678,0.001653,0.00165,0.001642,0.001658,0.001632,0.001628,0.00164,0.001632,0.00162,0.001635,0.001641,0.001627,0.00175,0.001632,0.001649,0.001635,0.001663,0.001629,0.001651,0.001631,0.00164,0.00163,0.00169,0.001633,0.001657,0.00185,0.001701,0.001652,0.001656,0.001637,0.001644,0.001634,0.001644,0.001633,0.00163,0.001625,0.001625,0.00166,0.001635,0.001645,0.001629,0.001702,0.001841,0.001646,0.001632,0.001639,0.001639,0.001659,0.001622,0.001672,0.001991,0.001676,0.001643,0.001674,0.001626,0.001658,0.001624,0.001729,0.001656,0.001681,0.001637,0.00165,0.001638,0.001648,0.001631,0.001638,0.00162,0.001629,0.00164,0.001621,0.001641,0.001689,0.00165,0.001634,0.001659,0.001639,0.001643,0.001631,0.001652,0.002051,0.001653,0.001634,0.001644,0.001628,0.001636,0.001628,0.00166,0.001646,0.001667,0.001647,0.001708,0.00163,0.001667,0.001637,0.001656,0.001631,0.001623,0.001626,0.001655,0.001638,0.001643,0.001651,0.001682,0.001644,0.001637,0.001829,0.00193,0.002016,0.001701,0.001648,0.001653,0.001628,0.001644,0.001644,0.001636,0.001642,0.001632,0.001644,0.001629,0.001652,0.00163,0.001635,0.001623,0.001691,0.001638,0.001651,0.001631,0.001653,0.001633,0.001648,0.00164,0.00163,0.001623,0.001633,0.001631,0.001638,0.001718,0.001633,0.001645,0.001632,0.001655,0.001638,0.00186,0.001632,0.001654,0.001827,0.001683,0.001629,0.001694,0.001626,0.001641,0.001627,0.001641,0.001627,0.001663,0.001647,0.001709,0.001659,0.001813,0.001644,0.001678,0.001773,0.001879,0.001756,0.00201,0.001776,0.001744,0.001633,0.001734,0.00168,0.001676,0.001633,0.001706,0.001637,0.00165,0.001633,0.001659,0.001633,0.00165,0.00163,0.001645,0.001729,0.001738,0.001644,0.001655,0.001677,0.001654,0.001635,0.001637,0.001635,0.001639,0.00165,0.001634,0.001643,0.001623,0.001708,0.001637,0.001661,0.001625,0.001649,0.001634,0.001672,0.001634,0.001652,0.001632,0.001646,0.002098,0.002439,0.002328,0.001657,0.00166,0.001688,0.001647,0.001636,0.001632,0.001638,0.001633,0.001632,0.001633,0.001646,0.001629,0.001655,0.001628,0.001648,0.001635,0.001648,0.001635,0.001698,0.001632,0.001654,0.001634,0.001647,0.001639,0.001642,0.001629,0.001643,0.001692,0.001652,0.001679,0.001635,0.001866,0.002452,0.002476,0.001858,0.002404,0.002322,0.00186,0.001844,0.001684,0.001647,0.001681,0.001644,0.001661,0.001663,0.001659,0.001645,0.001676,0.001636,0.001719,0.001631,0.001707,0.001634,0.001664,0.001632,0.001661,0.001641,0.00167,0.001629,0.001644,0.001635,0.001638,0.00171,0.001641,0.001641,0.001638,0.001644,0.001634,0.00165,0.00163,0.001649,0.001631,0.001659,0.001629,0.001679,0.001637,0.001661,0.001648,0.001657,0.001643,0.001649,0.001638,0.001647,0.001649,0.001652,0.001629,0.001646,0.001634,0.00165,0.001636,0.001634,0.001632,0.001714,0.001649,0.001636,0.001654,0.001628,0.001644,0.001639,0.001646,0.001637,0.001652,0.001643,0.001653,0.001642,0.001652,0.001631,0.001654,0.001752,0.001686,0.001659,0.001728,0.001638,0.00165,0.001654,0.001646,0.001639,0.001644,0.001631,0.001637,0.001634,0.001632,0.001627,0.001635,0.00166,0.001638,0.001649,0.001634,0.001655,0.001636,0.001651,0.001629,0.001648,0.001628,0.001648,0.001638,0.001649,0.001637,0.001648,0.001638,0.001642,0.001693,0.001634,0.001629,0.001635,0.001641,0.001627,0.001647,0.001635,0.001645,0.001642,0.001644,0.001635,0.001648,0.001631,0.001645,0.001631,0.00164,0.001637,0.00165,0.00167,0.001652,0.001635,0.001656,0.001632,0.001699,0.001647,0.001633,0.001631,0.00163,0.001634,0.001638,0.001649,0.001636,0.001649,0.001693,0.001668,0.001635,0.001676,0.001635,0.001642,0.001631,0.001645,0.001629,0.001673,0.001639,0.001659,0.001647,0.00165,0.001634,0.001651,0.001635,0.001628,0.001632,0.001633,0.001631,0.001639,0.001659,0.001639,0.001652,0.001638,0.001649,0.00165,0.001647,0.001631,0.00164,0.001632,0.00165,0.001679,0.001648,0.00165,0.001657,0.001636,0.00165,0.001634,0.001649,0.001629,0.001636,0.00164,0.001628,0.00165,0.001705,0.001681,0.001742,0.001688,0.001698,0.001796,0.001698,0.001709,0.001675,0.00169,0.00176,0.001698,0.001647,0.001655,0.001628,0.001649,0.001629,0.001674,0.001639,0.001652,0.001638,0.001655,0.001738,0.001668,0.001632,0.001649,0.001637,0.001659,0.001804,0.001838,0.001713,0.001645,0.001652,0.001659,0.001648,0.001653,0.001636,0.001665,0.001653,0.001651,0.001636,0.001629,0.001634,0.001636,0.001651,0.001639,0.001652,0.001648,0.001666,0.001646,0.001648,0.001636,0.001643,0.00164,0.00164,0.001635,0.001652,0.001637,0.001656,0.00165,0.001732,0.001635,0.001649,0.001643,0.00168,0.001627,0.001633,0.001631,0.001636,0.00166,0.001644,0.001651,0.00164,0.001649,0.001643,0.00165,0.001636,0.001643,0.001635,0.001753,0.001642,0.001661,0.00164,0.001656,0.001659,0.002022,0.001642,0.001665,0.00165,0.001663,0.001659,0.001649,0.00163,0.001644,0.001635,0.001655,0.001821,0.001688,0.001667,0.001671,0.00165,0.001646,0.001643,0.001647,0.001636,0.001652,0.001654,0.001647,0.001663,0.001641,0.001665,0.001655,0.001664,0.001641,0.001657,0.001638,0.00165,0.001636,0.001664,0.00164,0.001663,0.001914,0.001664,0.001645,0.001843,0.001692,0.001685,0.001632,0.001751,0.001638,0.001659,0.001652,0.001648,0.001638,0.001644,0.001649,0.001709,0.001641,0.001638,0.00164,0.00164,0.001657,0.001638,0.001762,0.001637,0.001678,0.001634,0.001647,0.001855,0.002444,0.002162,0.001653,0.001653,0.001692,0.001708,0.001634,0.001648,0.001638,0.001653,0.001631,0.001654,0.001659,0.001645,0.001659,0.001644,0.001713,0.001637,0.001657,0.001655,0.001647,0.00163,0.001663,0.001634,0.00165,0.001641,0.001653,0.001645,0.001655,0.001675,0.001649,0.001651,0.001654,0.00165,0.001651,0.001635,0.001642,0.00165,0.001656,0.001685,0.001641,0.001644,0.001645,0.001652,0.001642,0.001654,0.001636,0.00165,0.001728,0.001664,0.001637,0.001658,0.00164,0.001695,0.001641,0.001653,0.00164,0.001671,0.001646,0.001733,0.001644,0.001681,0.001638,0.001669,0.001653,0.001665,0.001636,0.001672,0.001647,0.001638,0.00164,0.00164,0.001686,0.001645,0.00169,0.001639,0.00166,0.001634,0.001898,0.00164,0.001671,0.001648,0.001673,0.001635,0.001698,0.001646,0.001695,0.001641,0.001662,0.001653,0.001654,0.001638,0.001655,0.001641,0.001665,0.001705,0.001673,0.001655,0.001652,0.001637,0.001646,0.001643,0.001643,0.00165,0.001648,0.001708,0.001646,0.001684,0.001827,0.001644,0.001658,0.001652,0.001648,0.001661,0.001644,0.001692,0.001645,0.001835,0.001644,0.001658,0.001653,0.001656,0.001648,0.001659,0.001738,0.001819,0.001646,0.001707,0.001671,0.001698,0.001657,0.001673,0.001641,0.001681,0.001644,0.001695,0.001638,0.001678,0.001703,0.001653,0.001645,0.001652,0.001652,0.001706,0.001657,0.001659,0.001657,0.001655,0.001639,0.001659,0.001641,0.001655,0.001635,0.001634,0.001692,0.001668,0.001668,0.00164,0.001643,0.001642,0.001667,0.001649,0.001657,0.001643,0.001699,0.001646,0.001677,0.001643,0.001712,0.001831,0.001811,0.001724,0.001745,0.001839,0.002009,0.002416,0.002107,0.002645,0.002615,0.002595,0.002652,0.002621,0.002631,0.002603,0.002589,0.002641,0.00267,0.002621,0.002598,0.002631,0.002382,0.002041,0.002261,0.002156,0.001648,0.001647,0.001825,0.001801,0.001664,0.001634,0.00164,0.00164,0.001638,0.001637,0.001676,0.001643,0.001676,0.001645,0.001692,0.001641,0.001678,0.001646,0.001706,0.00165,0.001696,0.001642,0.001649,0.001636,0.001661,0.001673,0.00166,0.001675,0.001977,0.001658,0.001662,0.001719,0.002149,0.002524,0.002491,0.002116,0.001635,0.001724,0.002439,0.001968,0.001902,0.002638,0.002623,0.002614,0.002649,0.002597,0.002501,0.002736,0.002685,0.002717,0.002753,0.002712,0.002648,0.002664,0.002798,0.002763,0.002615,0.002757,0.002641,0.002601,0.002621,0.002671,0.002637,0.0026,0.00264,0.002617,0.002573,0.002706,0.002765,0.002642,0.002664,0.002627,0.002653,0.002641,0.002554,0.004293,0.002635,0.00262,0.002654,0.002663,0.002546,0.002489,0.002597,0.00266,0.002578,0.002538,0.002629,0.002793,0.002671,0.002666,0.002743,0.002794,0.002621,0.002622,0.002632,0.002585,0.002609,0.002716,0.00263,0.002685,0.002732,0.00267,0.002751,0.00248,0.002485,0.002487,0.002607,0.002758,0.001846,0.001646,0.001656,0.001763,0.001715,0.001652,0.001695,0.001644,0.00169,0.001653,0.001708,0.00166,0.002444,0.002766,0.002654,0.001739,0.002649,0.003375,0.002776,0.00262,0.002599,0.002608,0.002611,0.002697,0.002441,0.002697,0.002705,0.002653,0.002559,0.002632,0.002676,0.002396,0.002719,0.002611,0.002534,0.002674,0.002731,0.002848,0.002914,0.002544,0.002352,0.002375,0.001774,0.002183,0.001841,0.001795,0.001768,0.001721,0.001811,0.001797,0.001845,0.001725,0.001758,0.001725,0.00181,0.001733,0.001916,0.001929,0.002028,0.001761,0.00165,0.001706,0.001649,0.001691,0.001667,0.001641,0.00164,0.001701,0.001682,0.002273,0.002508,0.001722,0.001663,0.001726,0.001651,0.002016,0.001652,0.001685,0.001697,0.001679,0.001647,0.001692,0.001645,0.001727,0.001649,0.001694,0.002221,0.002537,0.002544,0.002589,0.002587,0.003172,0.002538,0.002578,0.001842,0.002283,0.00175,0.001703,0.001654,0.001727,0.001702,0.00173,0.001652,0.00168,0.001653,0.001677,0.001648,0.001675,0.001643,0.001701,0.001647,0.001716,0.001646,0.001678,0.001686,0.001799,0.00165,0.001675,0.001649,0.001666,0.001667,0.001715,0.001647,0.001665,0.001672,0.001682,0.001646,0.001659,0.001701,0.001692,0.001671,0.001641,0.001639,0.001642,0.001656,0.001641,0.001671,0.001785,0.002288,0.002569,0.002581,0.001988,0.001948,0.002199,0.002279,0.001662,0.001683,0.001681,0.001728,0.00165,0.001684,0.001715,0.001734,0.001661,0.001696,0.001681,0.001687,0.001657,0.001739,0.001652,0.001684,0.00165,0.001693,0.001648,0.001676,0.001643,0.001679,0.001643,0.001695,0.001664,0.001688,0.00165,0.001665,0.001674,0.001705,0.001657,0.001672,0.001736,0.001664,0.00166,0.001662,0.001652,0.001645,0.001666,0.001683,0.001648,0.001651,0.001643,0.001655,0.001689,0.001653,0.001661,0.001655,0.001679,0.001647,0.001724,0.00165,0.001665,0.001729,0.001706,0.001648,0.001732,0.00164,0.001661,0.001645,0.001682,0.001639,0.001663,0.001658,0.001689,0.001662,0.001669,0.001652,0.001659,0.001653,0.001662,0.001656,0.001714,0.001651,0.001674,0.001669,0.001732,0.001644,0.001643,0.001675,0.001671,0.001664,0.001663,0.001803,0.001688,0.00167,0.001778,0.001758,0.001751,0.001708,0.001743,0.001653,0.001813,0.001679,0.001711,0.001674,0.001667,0.00165,0.001655,0.001653,0.001664,0.001766,0.001661,0.001659,0.001656,0.001857,0.001691,0.001742,0.001739,0.001798,0.001786,0.001748,0.001776,0.001738,0.001784,0.001732,0.001734,0.001747,0.001706,0.001663,0.001667,0.001657,0.001699,0.001651,0.001666,0.00167,0.001703,0.001652,0.001682,0.001658,0.001918,0.001648,0.001661,0.00165,0.001655,0.001655,0.001644,0.001698,0.001664,0.001736,0.001765,0.001662,0.001755,0.001648,0.00168,0.001661,0.001677,0.001655,0.001665,0.001656,0.001644,0.001738,0.001673,0.001681,0.001656,0.001842,0.001904,0.001654,0.00165,0.001674,0.001664,0.001685,0.001665,0.001691,0.001654,0.001718,0.001651,0.001691,0.001649,0.001692,0.001738,0.001711,0.001653,0.001696,0.001661,0.001714,0.001659,0.001697,0.001653,0.001819,0.001692,0.001732,0.001651,0.001695,0.001946,0.001709,0.00165,0.00172,0.001656,0.001677,0.001661,0.001689,0.00166,0.001681,0.001652,0.001691,0.001644,0.001706,0.00165,0.001668,0.00167,0.001663,0.001775,0.00167,0.001653,0.001674,0.001698,0.001666,0.001669,0.001678,0.001721,0.001657,0.001666,0.001679,0.00165,0.001649,0.00166,0.00166,0.001675,0.001661,0.001662,0.001655,0.001661,0.001655,0.001662,0.001795,0.001708,0.001652,0.001714,0.001655,0.00169,0.001674,0.001707,0.001645,0.001677,0.001711,0.00169,0.001649,0.001669,0.001644,0.00166,0.00166,0.001667,0.001654,0.001677,0.001654,0.001665,0.00166,0.001661,0.001658,0.001649,0.001786,0.001685,0.001678,0.001657,0.001647,0.001651,0.001667,0.00165,0.001665,0.001645,0.001699,0.00165,0.001664,0.001653,0.001666,0.001681,0.001688,0.001704,0.00167,0.001648,0.001665,0.001657,0.001659,0.001649,0.001659,0.001645,0.001669,0.001756,0.001725,0.001654,0.00168,0.001666,0.00171,0.001653,0.00168,0.002009,0.001717,0.001704,0.001687,0.001656,0.00169,0.001693,0.001705,0.001654,0.001686,0.001654,0.001673,0.001666,0.001661,0.001652,0.001643,0.001648,0.001644,0.00165,0.001676,0.001647,0.001657,0.001697,0.001683,0.001675,0.001654,0.001673,0.001881,0.001665,0.001693,0.001668,0.001652,0.001679,0.001653,0.001677,0.00165,0.00166,0.001649,0.001681,0.001656,0.001663,0.001644,0.001667,0.001665,0.001712,0.001656,0.001704,0.001719,0.001699,0.001657,0.001666,0.001651,0.001668,0.001682,0.00165,0.001653,0.001652,0.001648,0.00165,0.001647,0.001651,0.001667,0.001793,0.001901,0.001651,0.001653,0.001649,0.00167,0.001657,0.001667,0.001691,0.001672,0.001651,0.001815,0.001711,0.00169,0.001661,0.001677,0.001652,0.001663,0.001795,0.001697,0.001653,0.001691,0.001668,0.00167,0.00166,0.001657,0.001664,0.001668,0.001646,0.00168,0.001704,0.001684,0.001665,0.001712,0.001668,0.001677,0.001668,0.001672,0.001658,0.001667,0.002024,0.001712,0.001672,0.001756,0.001662,0.00169,0.001662,0.001682,0.001657,0.001684,0.001657,0.001695,0.001672,0.001665,0.001652,0.001648,0.00165,0.00165,0.001649,0.001711,0.00167,0.001653,0.001682,0.001689,0.001669,0.001653,0.001662,0.001654,0.001665,0.001677,0.001667,0.001652,0.00166,0.001645,0.001663,0.001652,0.001736,0.00165,0.00167,0.001657,0.001686,0.001664,0.00167,0.001698,0.001671,0.001693,0.001665,0.00177,0.001732,0.00168,0.001669,0.001651,0.001672,0.001666,0.001948,0.001657,0.001676,0.001653,0.001646,0.001738,0.001648,0.00165,0.001652,0.001661,0.001659,0.001669,0.001652,0.001667,0.001715,0.001681,0.001832,0.001695,0.001658,0.001704,0.001692,0.001768,0.001664,0.001732,0.001736,0.001655,0.001663,0.001674,0.001683,0.001688,0.001666,0.001674,0.001657,0.001675,0.00166,0.001674,0.001656,0.00167,0.001735,0.001716,0.001653,0.001716,0.001724,0.001738,0.001759,0.001715,0.001755,0.001688,0.0021,0.001791,0.001722,0.001728,0.001654,0.001687,0.001661,0.001694,0.001652,0.001692,0.001655,0.001687,0.001653,0.001688,0.001659,0.001696,0.001657,0.001666,0.001691,0.001681,0.001651,0.001676,0.00169,0.001702,0.001651,0.001691,0.001659,0.001679,0.001653,0.001689,0.001659,0.001729,0.001668,0.001678,0.001652,0.001662,0.001661,0.001647,0.00165,0.001649,0.001651,0.001654,0.001668,0.001659,0.001669,0.00166,0.001669,0.001662,0.001698,0.001658,0.001673,0.001656,0.001699,0.001661,0.001715,0.001683,0.001671,0.001657,0.001667,0.001653,0.001667,0.001649,0.001673,0.001674,0.00173,0.00166,0.001673,0.001659,0.001668,0.001655,0.001664,0.001655,0.001681,0.001661,0.001681,0.001648,0.001652,0.001652,0.001659,0.001696,0.001657,0.001667,0.001653,0.001684,0.001657,0.001665,0.001653,0.001672,0.001663,0.001668,0.001661,0.001675,0.00169,0.001685,0.001871,0.001789,0.001788,0.001687,0.001759,0.001913,0.001872,0.002212,0.001785,0.001739,0.002007,0.001693,0.001767,0.001886,0.001809,0.001727,0.001788,0.001753,0.001758,0.001805,0.001751,0.001797,0.001674,0.001662,0.002077,0.001747,0.001659,0.00167,0.001673,0.001684,0.001653,0.001652,0.001659,0.001648,0.001679,0.001684,0.001675,0.001707,0.001688,0.001661,0.001673,0.001665,0.001692,0.001669,0.001671,0.001654,0.001669,0.001659,0.001684,0.001681,0.001673,0.001654,0.001667,0.001663,0.001714,0.001699,0.001672,0.00166,0.002413,0.002472,0.001736,0.001705,0.0017,0.001687,0.001657,0.00165,0.001652,0.001653,0.001666,0.001651,0.001677,0.001661,0.00167,0.001661,0.001678,0.001661,0.001666,0.001669,0.001689,0.001656,0.00171,0.001655,0.001673,0.001654,0.001661,0.001649,0.001706,0.001653,0.00167,0.001665,0.001674,0.001659,0.0017,0.001671,0.001673,0.001663,0.001669,0.001662,0.001672,0.001671,0.001675,0.001655,0.001654,0.001667,0.001649,0.001653,0.001663,0.001653,0.001675,0.001716,0.001663,0.00168,0.001656,0.00167,0.001662,0.001672,0.00167,0.001671,0.001657,0.00169,0.001656,0.001666,0.001662,0.001674,0.001671,0.00203,0.001666,0.001788,0.001661,0.001719,0.001719,0.001713,0.00166,0.00167,0.001697,0.00167,0.001658,0.001694,0.00166,0.001899,0.001656,0.001672,0.001789,0.001673,0.00166,0.001667,0.001822,0.001677,0.001653,0.00177,0.001742,0.001671,0.001653,0.001667,0.001737,0.001801,0.001683,0.001669,0.001893,0.001691,0.001711,0.001672,0.001655,0.001665,0.001661,0.001675,0.001707,0.001678,0.001665,0.001676,0.001723,0.002473,0.002331,0.001705,0.002006,0.001694,0.001671,0.001668,0.001677,0.00169,0.001655,0.001691,0.001655,0.001656,0.001655,0.001672,0.001652,0.001671,0.001664,0.001687,0.00166,0.001674,0.001668,0.00167,0.001662,0.001674,0.001661,0.001667,0.00171,0.001683,0.001657,0.001665,0.00165,0.001666,0.001666,0.001673,0.001729,0.00168,0.001912,0.001677,0.001651,0.001673,0.001665,0.00197,0.001666,0.001677,0.001687,0.00167,0.00166,0.001685,0.001925,0.002153,0.001674,0.001695,0.001673,0.001697,0.001659,0.001686,0.00166,0.001711,0.001709,0.001705,0.001654,0.001671,0.001672,0.00168,0.001733,0.001725,0.001662,0.00168,0.001878,0.002097,0.001728,0.001704,0.001664,0.001694,0.001679,0.001701,0.001659,0.00172,0.001845,0.001708,0.001663,0.001679,0.001676,0.001673,0.001703,0.001739,0.001665,0.001708,0.001655,0.001706,0.001657,0.002344,0.002541,0.001816,0.002128,0.00257,0.002188,0.002357,0.001866,0.001701,0.001663,0.001709,0.001664,0.001696,0.002026,0.001769,0.002317,0.002398,0.002478,0.001973,0.001923,0.002422,0.002716,0.002592,0.002085,0.001782,0.001752,0.002031,0.001746,0.001762,0.001733,0.001781,0.002074,0.002589,0.002599,0.002219,0.001988,0.00271,0.001841,0.002769,0.002508,0.001811,0.001947,0.002321,0.002269,0.002032,0.002851,0.002819,0.002655,0.00282,0.002679,0.002617,0.002629,0.00267,0.002643,0.002629,0.002635,0.002692,0.002679,0.002673,0.002709,0.002903,0.002564,0.002621,0.00299,0.002654,0.002696,0.002668,0.00267,0.002655,0.002694,0.002644,0.002626,0.002672,0.00259,0.002827,0.002842,0.002821,0.002759,0.00232,0.002483,0.00178,0.001828,0.002277,0.001703,0.001692,0.001707,0.001702,0.001692,0.001672,0.00167,0.001682,0.001967,0.001664,0.00169,0.001667,0.001697,0.001863,0.001709,0.001682,0.001701,0.001672,0.001937,0.002828,0.002625,0.002648,0.002844,0.002863,0.002685,0.002671,0.002591,0.002417,0.001695,0.00174,0.001839,0.002499,0.002159,0.002287,0.002196,0.002818,0.002845,0.002818,0.002767,0.002665,0.002624,0.002642,0.002694,0.002603,0.002567,0.002501,0.002606,0.002577,0.002678,0.002691,0.002702,0.002689,0.002608,0.00183,0.001717,0.001722,0.001777,0.001722,0.001698,0.001791,0.001658,0.001712,0.001738,0.001776,0.001729,0.001761,0.001682,0.001728,0.00167,0.001747,0.00167,0.001737,0.001661,0.001699,0.001693,0.001736,0.001664,0.00175,0.001662,0.00169,0.001697,0.001684,0.00167,0.001722,0.001668,0.001688,0.001669,0.001682,0.001666,0.001751,0.001708,0.001709,0.001684,0.001691,0.001683,0.001696,0.001664,0.001671,0.001673,0.001695,0.001748,0.001885,0.00172,0.001713,0.001675,0.001682,0.001663,0.001726,0.00167,0.0017,0.001665,0.001695,0.001671,0.001715,0.00167,0.001697,0.001665,0.001808,0.001867,0.001895,0.001751,0.00171,0.001665,0.001703,0.001664,0.001696,0.001702,0.001696,0.001666,0.001714,0.001662,0.001699,0.001668,0.00176,0.001663,0.001687,0.001662,0.001672,0.001663,0.001675,0.001659,0.001685,0.001656,0.001679,0.001674,0.00168,0.001667,0.001676,0.001713,0.001684,0.001681,0.001687,0.001897,0.001685,0.001671,0.001679,0.001665,0.001673,0.00166,0.001675,0.001677,0.001661,0.001659,0.001662,0.001669,0.001671,0.001665,0.00166,0.001663,0.00166,0.001671,0.001675,0.001702,0.001671,0.001681,0.001664,0.001678,0.001665,0.001675,0.001664,0.00169,0.001665,0.001674,0.001668,0.00167,0.00166,0.001679,0.001659,0.001668,0.001667,0.001676,0.00167,0.001683,0.001666,0.001678,0.001668,0.001684,0.001673,0.001718,0.001665,0.001679,0.001678,0.001684,0.001925,0.001698,0.001667,0.001698,0.00167,0.001692,0.001665,0.001693,0.001682,0.001659,0.00166,0.001925,0.001684,0.00168,0.001662,0.001661,0.00166,0.001665,0.001678,0.001657,0.001668,0.001664,0.001689,0.001671,0.001681,0.001667,0.00168,0.001664,0.001755,0.001747,0.001681,0.001677,0.001682,0.001667,0.001675,0.00167,0.001681,0.001666,0.00169,0.001669,0.001729,0.00166,0.001669,0.001662,0.001683,0.001664,0.001676,0.00167,0.001689,0.001683,0.001687,0.001683,0.001688,0.001669,0.001676,0.001664,0.00168,0.001662,0.001686,0.001681,0.001731,0.001667,0.001664,0.001673,0.00166,0.001661,0.001658,0.001661,0.001663,0.001694,0.00167,0.001684,0.00167,0.001679,0.001678,0.001686,0.001665,0.001679,0.001667,0.001701,0.001668,0.001693,0.001672,0.001681,0.001669,0.001677,0.001663,0.001671,0.00166,0.001675,0.001659,0.001684,0.001697,0.001703,0.001731,0.001687,0.001671,0.00168,0.001677,0.001694,0.001678,0.001687,0.001665,0.001685,0.00167,0.001681,0.001666,0.00168,0.001673,0.00166,0.001671,0.001664,0.001659,0.001663,0.001668,0.001666,0.001677,0.001703,0.001696,0.00167,0.001696,0.001668,0.001682,0.001668,0.001734,0.001671,0.00175,0.001671,0.001701,0.001668,0.001713,0.001672,0.001715,0.001668,0.001695,0.001667,0.001714,0.001661,0.001696,0.001661,0.001707,0.001665,0.001679,0.001663,0.001692,0.001672,0.001685,0.001672,0.001716,0.001667,0.001696,0.001683,0.001682,0.001695,0.001738,0.001673,0.001687,0.001668,0.001686,0.001705,0.001681,0.001678,0.001684,0.001669,0.001662,0.00167,0.00166,0.001664,0.001661,0.001663,0.001672,0.001696,0.001673,0.001689,0.001671,0.001685,0.00167,0.00168,0.001672,0.001712,0.001671,0.00169,0.001673,0.001679,0.00167,0.001704,0.001667,0.001676,0.001662,0.001699,0.001668,0.001682,0.001663,0.001701,0.001669,0.001704,0.001668,0.001689,0.001668,0.001711,0.001726,0.001751,0.001703,0.001716,0.00167,0.001683,0.00167,0.001711,0.001673,0.001684,0.001669,0.001682,0.001679,0.001681,0.00167,0.001685,0.001677,0.001662,0.001661,0.001663,0.001668,0.001667,0.00169,0.001694,0.00167,0.001956,0.001682,0.001685,0.001685,0.001694,0.001672,0.001675,0.00168,0.001672,0.001667,0.001662,0.001664,0.001666,0.001677,0.001676,0.001698,0.001679,0.001716,0.001676,0.001697,0.001673,0.001694,0.00167,0.001681,0.001672,0.001683,0.001671,0.001698,0.001669,0.001697,0.00191,0.001741,0.001685,0.001689,0.001681,0.001715,0.00173,0.001733,0.001684,0.001694,0.001675,0.001699,0.001681,0.001703,0.001688,0.001695,0.001686,0.001704,0.001676,0.001697,0.001669,0.001678,0.001683,0.001692,0.00173,0.001702,0.001667,0.001686,0.00167,0.001675,0.001668,0.001712,0.001852,0.001743,0.001662,0.00168,0.001666,0.001685,0.001662,0.001679,0.001665,0.001697,0.001692,0.00169,0.001736,0.002034,0.00167,0.0018,0.001928,0.001689,0.001675,0.001684,0.001674,0.001684,0.00167,0.001676,0.001664,0.001681,0.001667,0.001682,0.001664,0.001677,0.001691,0.001683,0.001675,0.001747,0.001676,0.001699,0.001943,0.00169,0.001668,0.001936,0.001693,0.00175,0.001664,0.001702,0.001697,0.001723,0.001667,0.001695,0.001667,0.001703,0.001678,0.001688,0.001671,0.001694,0.001674,0.001695,0.001682,0.001697,0.001671,0.001691,0.001691,0.001691,0.001676,0.001686,0.001789,0.002111,0.001674,0.001704,0.001696,0.001711,0.001677,0.001701,0.001669,0.001705,0.001677,0.001709,0.001676,0.001687,0.001675,0.001692,0.001685,0.001684,0.001675,0.001693,0.001673,0.001685,0.001685,0.001682,0.001675,0.001685,0.001674,0.001676,0.001667,0.001671,0.001716,0.00168,0.001678,0.001667,0.001667,0.00167,0.001668,0.001665,0.001697,0.001668,0.001696,0.00168,0.001703,0.00169,0.001689,0.001677,0.001692,0.00168,0.001691,0.001675,0.00169,0.001675,0.001721,0.001677,0.001709,0.001674,0.001688,0.001682,0.001683,0.001668,0.001677,0.001672,0.001685,0.001672,0.001689,0.001669,0.001726,0.001687,0.001678,0.001669,0.001694,0.001674,0.002121,0.001688,0.001703,0.001667,0.002017,0.001699,0.001718,0.001676,0.001714,0.002442,0.002448,0.001731,0.00172,0.001711,0.001672,0.00171,0.00174,0.001687,0.001691,0.001737,0.001675,0.001687,0.001667,0.001708,0.001673,0.001746,0.001681,0.001694,0.001731,0.001689,0.001689,0.00169,0.001693,0.00169,0.001682,0.001696,0.001674,0.001714,0.00168,0.001693,0.001687,0.001697,0.001671,0.001687,0.00169,0.001698,0.001686,0.001708,0.001678,0.001672,0.001686,0.00167,0.00169,0.00168,0.001677,0.001671,0.001926,0.002591,0.002126,0.001757,0.001681,0.001723,0.001679,0.001691,0.001677,0.001705,0.001675,0.001687,0.001677,0.001708,0.001676,0.001691,0.001673,0.00169,0.001677,0.001683,0.001666,0.001689,0.00167,0.001698,0.001671,0.00168,0.001667,0.002108,0.001876,0.001708,0.001672,0.001686,0.001675,0.001701,0.001677,0.001687,0.001671,0.001685,0.001682,0.001678,0.00168,0.001689,0.001672,0.001683,0.001671,0.001683,0.001665,0.00169,0.001682,0.001716,0.001679,0.001702,0.001672,0.001733,0.001689,0.001701,0.001675,0.001719,0.001679,0.001751,0.001675,0.001685,0.001675,0.002008,0.001695,0.001695,0.001676,0.001687,0.001675,0.001687,0.001674,0.001686,0.001677,0.001687,0.001683,0.001696,0.0017,0.001691,0.001676,0.001668,0.001671,0.001672,0.001669,0.001671,0.001687,0.001667,0.001669,0.00168,0.001722,0.001677,0.001689,0.001723,0.001694,0.001677,0.001706,0.001677,0.001774,0.001727,0.001737,0.001694,0.001714,0.001691,0.001708,0.001685,0.001718,0.00168,0.001701,0.001686,0.00171,0.00169,0.001697,0.001725,0.002012,0.001703,0.001739,0.001741,0.001679,0.001687,0.001679,0.001681,0.001686,0.001682,0.001678,0.001711,0.0017,0.001682,0.001697,0.001676,0.001708,0.001688,0.001749,0.001686,0.001697,0.001676,0.001709,0.001674,0.001684,0.001683,0.001687,0.00168,0.001681,0.001669,0.001684,0.001681,0.001715,0.001687,0.001746,0.001685,0.001695,0.001802,0.001711,0.001681,0.001695,0.00168,0.001761,0.001958,0.001699,0.00167,0.001715,0.001674,0.001696,0.001678,0.001705,0.001755,0.001717,0.001686,0.001708,0.001692,0.001722,0.001683,0.001704,0.001683,0.001743,0.001693,0.00172,0.001684,0.00171,0.001738,0.001732,0.001698,0.001709,0.001679,0.001697,0.001681,0.001717,0.001684,0.001701,0.001682,0.001694,0.001693,0.001694,0.001713,0.001953,0.001686,0.001725,0.001769,0.001721,0.001685,0.001705,0.001693,0.001694,0.001747,0.001728,0.001684,0.001723,0.001685,0.001753,0.001738,0.001703,0.001688,0.001779,0.001716,0.001795,0.001713,0.001706,0.001686,0.001805,0.001741,0.001758,0.001756,0.001784,0.002106,0.001697,0.001683,0.001701,0.001749,0.001748,0.001698,0.001695,0.001696,0.001682,0.001686,0.00175,0.00168,0.00169,0.001671,0.001673,0.001671,0.001672,0.001671,0.00175,0.001682,0.00167,0.001717,0.001688,0.001694,0.0017,0.001688,0.002062,0.001835,0.001678,0.002135,0.001779,0.001722,0.001737,0.001761,0.001688,0.001739,0.001686,0.001714,0.00168,0.001716,0.00168,0.001724,0.001702,0.001699,0.001688,0.001708,0.001684,0.001698,0.001679,0.001692,0.00168,0.001697,0.001693,0.001694,0.002089,0.001714,0.001716,0.001702,0.001701,0.001726,0.00168,0.0017,0.001685,0.001696,0.001734,0.001702,0.001708,0.001728,0.001683,0.001696,0.001681,0.001707,0.001698,0.001726,0.001683,0.001732,0.001689,0.001698,0.001784,0.001706,0.001691,0.001837,0.001719,0.001699,0.001693,0.001693,0.001689,0.001711,0.001682,0.001713,0.001689,0.001698,0.001699,0.001695,0.001689,0.001703,0.001681,0.001696,0.00188,0.001722,0.001682,0.001826,0.001699]

x_axis = list(np.arange(0,len(new_time_insertion),1))

fig = plt.figure(figsize = (10,8))
plt.plot(x_axis, new_time_insertion)
plt.xlabel('No of elements')
plt.ylabel('Time in seconds')
plt.title('Time for insertion of key from AVL Tree')
plt.show()
