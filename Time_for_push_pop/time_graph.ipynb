# %%
import pandas as pd

db_back = pd.read_csv('push_back.csv')
df_back = pd.DataFrame(db_back)

db_front = pd.read_csv('push_front.csv')
df_front = pd.DataFrame(db_front)

db_pop = pd.read_csv('pop_back.csv')
df_pop = pd.DataFrame(db_pop)

df_back.plot(x = 'elements', y = 'time', title = 'push_back')
df_front.plot(x = 'elements', y = 'time', title = 'push_front')
df_pop.plot(x = 'elements', y = 'time', title = 'pop_back')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2f11e5e01591> in <module>
#      13 df_front.plot(x = 'elements', y = 'time', title = 'push_front')
#      14 df_pop.plot(x = 'elements', y = 'time', title = 'pop_back')
# ---> 15 plt.show()
#
# NameError: name 'plt' is not defined
